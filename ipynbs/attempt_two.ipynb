# %% [markdown]
# ## Syllable count attempt using spaCy syllables

# %%
import spacy
from spacy_syllables import SpacySyllables

nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("syllables", after="tagger")

assert nlp.pipe_names == ["tok2vec", "tagger", "syllables", "parser",  "attribute_ruler", "lemmatizer", "ner"]

count = 0 
text = ""
with open("sentences.txt", "r") as file:
    for line in file:
        # Split the sentence into the text and syllable count
        sentence, syllable_count = line.rsplit("(", 1)
        syllable_count = syllable_count.replace(" syllables)", "")
        text += sentence
        count += int(syllable_count)

# Print the results
print(text)

doc = nlp(text)
data = [(token.text, token._.syllables, token._.syllables_count) for token in doc]

sum = 0
for el in data:
    if el[2] is not None:
        sum += el[2]
# Out:
# She enjoys reading books and watching movies in her free time. I like to eat pizza and pasta. She sings and plays the guitar beautifully. He ran, jumped, and landed gracefully. My favorite colors are blue, green, and purple. They laughed, talked, and danced all night long. The movie was funny, exciting, and romantic. She walked her dog and went for a jog in the park. The cake was moist, flavorful, and delicious. He worked hard, studied diligently, and earned his degree. The sun was setting, the sky was pink, and the air was warm. She wore a red dress and matching heels to the party. He wrote, directed, and produced the award-winning film. They swam, snorkeled, and sunbathed on the beach. We listened to music, chatted, and had a drink at the bar. She loves to read and write stories. He worked hard and earned a promotion. The dog barked and wagged its tail excitedly. We can go for a walk or watch a movie. She's talented and hardworking, a rare combination. They played soccer and basketball after school. He cooked dinner and cleaned up the kitchen. The train arrived late but finally pulled into the station. She wore a yellow dress and a matching hat. The flowers were colorful and fragrant in the garden. We laughed, joked, and reminisced about old times. He played the guitar and sang a beautiful song. She woke up early and went for a run before work. They visited museums, art galleries, and historical sites. He read the book, watched the movie, and compared them. She studied hard and aced the test. We swam in the pool and lounged in the sun. He drank coffee, tea, and water throughout the day. She traveled to Paris, London, and Rome last summer. They ordered pizza, wings, and soda for the party. He drove to the store, bought groceries, and came home. She danced, sang, and performed on stage with confidence. They laughed, cried, and hugged each other tightly. We went to the beach, played volleyball, and had a picnic. He walked his dog, played fetch, and gave it a bath.

# %%
print("Syllable count according to GPT: ", count) 
print("Syllable count according to spaCy: ", sum)
print("Proportion spaCy/GPT: ", round(sum/count, 2))
# Out:
# Syllable count according to GPT:  584
# Syllable count according to spaCy:  461
# Proportion spaCy/GPT:  0.79

# %% [markdown]
# ---
#
# ## Parsing a batch of COCA corpus

# %%
import re

coca = ""
with open("coca-samples/text_acad.txt", "r") as file:
    for i in range(5):
        coca += file.readline()

regex_patterns = [r"@@\d{7}\b", r"@\s?(@\s?){8}@", r"<[ph]>"]
clean_coca = coca
for regex in regex_patterns:
    clean_coca = re.sub(regex, "", clean_coca)

print(clean_coca)

# %%
from trankit import Pipeline

p = Pipeline("english", gpu=False)

# %%
all = p(clean_coca)

# %%
all["sentences"][0]

# %%
with open("connllu.txt", "w") as file:
    for sentence in all["sentences"]:
        id = sentence["id"]
        text = sentence["text"]
        file.write(f"# sent_id = {id}\n")
        file.write(f"# text = {text}\n")

        for token in sentence["tokens"]:
            conllu_token = "{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}".format(
            token["id"],  # ID
            token["text"],  # FORM
            token["lemma"],  # LEMMA
            token["upos"],  # UPOS
            token["xpos"],  # XPOS
            "_",  # FEATS
            token["head"],  # HEAD
            token["deprel"],  # DEPREL
            "_",  # DEPS
            "_"  # MISC
            )
            file.write(f"{conllu_token}\n")
        
        file.write("\n")

# %% [markdown]
# ## Extract output to XML and retrieve it

# %%
from dict2xml import dict2xml
xml = dict2xml(all, wrap='root')

with open("coca_parsed/coca_sample_batch_1.xml", "w") as file:
    file.write(xml)

# %%
import xmltodict

with open("coca_parsed/coca_sample_batch_1.xml", "r", encoding='utf-8') as file:
    xml = file.read()

dict = xmltodict.parse(xml)

# %%
parsed = dict["root"]
parsed["sentences"]

# %% [markdown]
# ## Table with info

# %%
import pandas as pd

data = pd.read_csv("columns.csv", sep="\t")
df = pd.DataFrame(columns=data.columns)

# %%
sentences = all["sentences"]

info = {"sentences": []}

sent_id = 0

for sentence in sentences:

    doc = nlp(sentence["text"])
    syllable_count = 0
    for token in doc:
        if token._.syllables_count is not None:
            syllable_count += token._.syllables_count

    coordination = []
    current_sent = ""

    info["sentences"].append({"sent_id": sent_id + 1})
    info["sentences"][sent_id]["all_syllables"] = syllable_count
    info["sentences"][sent_id]["coordination"] = {}
    info["sentences"][sent_id]["coordination"]["conj_id"] = []
    info["sentences"][sent_id]["coordination"]["conj_word"] = []
    info["sentences"][sent_id]["coordination"]["parts_syllables"] = []
    info["sentences"][sent_id]["coordination"]["parts_tokens"] = []

    token_id = 0
    token_count = 0
    for token in sentence["tokens"]:
        token_id += 1
        token_count += 1
        if token["head"] == 0:
            info["sentences"][sent_id]["head_id"] = token_id
            info["sentences"][sent_id]["head_word"] = token["text"]
            info["sentences"][sent_id]["head_tag"] = token["upos"]
            try:
                info["sentences"][sent_id]["governor.ms"] = token["feats"]
            except KeyError:
                info["sentences"][sent_id]["governor.ms"] = " "

        if token["upos"] == "CCONJ":
            info["sentences"][sent_id]["coordination"]["conj_id"].append(token_id)
            info["sentences"][sent_id]["coordination"]["conj_word"].append(token["text"])
            coordination.append(current_sent)
            current_sent = ""
            info["sentences"][sent_id]["coordination"]["parts_tokens"].append(token_count - 1) 
            token_count = 0
        else:
            if token["text"] == ".":
                current_sent += token["text"]
            else:
                current_sent += token["text"] + " "
    coordination.append(current_sent)
    info["sentences"][sent_id]["coordination"]["parts_tokens"].append(token_count) 
    info["sentences"][sent_id]["coordination"]["coordination_text_parts"] = coordination

    for part in info["sentences"][sent_id]["coordination"]["coordination_text_parts"]:
        syllable_count_part = 0
        doc = nlp(part)
        for token in doc:
            if token._.syllables_count is not None:
                syllable_count_part += token._.syllables_count
        info["sentences"][sent_id]["coordination"]["parts_syllables"].append(syllable_count_part)

    sent_id += 1

# %%
info["sentences"]
# Out:
# [{'sent_id': 1,
#   'all_syllables': 81,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [81],
#    'parts_tokens': [70],
#    'coordination_text_parts': ['I think it is safe to say that ours is the only dining room in West Los Angeles on whose table -- an eight - foot - long , two - hundred - pound behemoth on which I have taken my meals for many years -- rest piles of photocopies of articles on suicide , all of which were printed in the Encyclopaedia Britannica over the past 220 years .']},
#   'head_id': 2,
#   'head_word': 'think',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 2,
#   'all_syllables': 21,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [21],
#    'parts_tokens': [14],
#    'coordination_text_parts': ['They represent the convergence of two crucially important strands in my own life .']},
#   'head_id': 2,
#   'head_word': 'represent',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 3,
#   'all_syllables': 72,
#   'coordination': {'conj_id': [45, 47],
#    'conj_word': ['and', 'but'],
#    'parts_syllables': [55, 2, 13],
#    'parts_tokens': [44, 1, 5],
#    'coordination_text_parts': ['Indeed , as I look at the articles , arrayed before me in fanlike tiers , I get the odd feeling that the old oak ruble on which I have eaten so many thousands of dinners has been set not with its customary china ',
#     'silver ',
#     'with my intellectual autobiography .']},
#   'head_id': 18,
#   'head_word': 'get',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 4,
#   'all_syllables': 18,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [18],
#    'parts_tokens': [11],
#    'coordination_text_parts': ['My special relationship with the Britannica is of long standing .']},
#   'head_id': 10,
#   'head_word': 'standing',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 5,
#   'all_syllables': 23,
#   'coordination': {'conj_id': [12],
#    'conj_word': ['and'],
#    'parts_syllables': [15, 7],
#    'parts_tokens': [11, 8],
#    'coordination_text_parts': ['It is relevant to report that I was a sickly child ',
#     'stayed home from school a great deal .']},
#   'head_id': 3,
#   'head_word': 'relevant',
#   'head_tag': 'ADJ',
#   'governor.ms': 'Degree=Pos'},
#  {'sent_id': 6,
#   'all_syllables': 51,
#   'coordination': {'conj_id': [17, 27],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [18, 10, 21],
#    'parts_tokens': [16, 9, 16],
#    'coordination_text_parts': ['The reader can readily imagine the sort of boy I was : frail , bookish , ',
#     'undersized ( I was small to begin with , ',
#     'continued to shrink , comparatively speaking , as I was double - promoted four ) .']},
#   'head_id': 5,
#   'head_word': 'imagine',
#   'head_tag': 'VERB',
#   'governor.ms': 'VerbForm=Inf'},
#  {'sent_id': 7,
#   'all_syllables': 51,
#   'coordination': {'conj_id': [6, 16],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [5, 11, 33],
#    'parts_tokens': [5, 9, 17],
#    'coordination_text_parts': ['Our house , fifteen miles ',
#     'seventy years from the one in which my wife ',
#     'I live today , resembled those of many Eastern European Jewish immigrant families with intellectual aspirations .']},
#   'head_id': 21,
#   'head_word': 'resembled',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 8,
#   'all_syllables': 33,
#   'coordination': {'conj_id': [13],
#    'conj_word': ['and'],
#    'parts_syllables': [12, 20],
#    'parts_tokens': [12, 19],
#    'coordination_text_parts': ['There were copies of Shakespeare , Tolstoy , Dostoyevsky , Conrad , ',
#     'Mann , diligently assembled from the local Lincoln Heights Library \'s list of " The 100 Best ." ']},
#   'head_id': 2,
#   'head_word': 'were',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 9,
#   'all_syllables': 22,
#   'coordination': {'conj_id': [6, 14],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [7, 11, 2],
#    'parts_tokens': [5, 7, 2],
#    'coordination_text_parts': ['There was a windup Victrola ',
#     'records of operatic arias sung by Caruso ',
#     'Farrar .']},
#   'head_id': 2,
#   'head_word': 'was',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 10,
#   'all_syllables': 52,
#   'coordination': {'conj_id': [1, 36],
#    'conj_word': ['And', 'and'],
#    'parts_syllables': [0, 45, 5],
#    'parts_tokens': [0, 34, 5],
#    'coordination_text_parts': ['',
#     "in the center of all this -- the jewel in the Shneidman family 's cultural crown - there was the Ninth Edition of the Britannica , enshrined in a Stickley bookcase with glass doors ",
#     'its own little key .']},
#   'head_id': 20,
#   'head_word': 'was',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 11,
#   'all_syllables': 29,
#   'coordination': {'conj_id': [19],
#    'conj_word': ['and'],
#    'parts_syllables': [25, 3],
#    'parts_tokens': [18, 3],
#    'coordination_text_parts': ['The suite of Craftsman furniture to which the bookcase belonged also included a sofa , a chair , ',
#     'a table .']},
#   'head_id': 12,
#   'head_word': 'included',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 12,
#   'all_syllables': 9,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [9],
#    'parts_tokens': [9],
#    'coordination_text_parts': ['All of them are in my home today .']},
#   'head_id': 7,
#   'head_word': 'home',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 13,
#   'all_syllables': 18,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [18],
#    'parts_tokens': [17],
#    'coordination_text_parts': ['Among the happiest hours of my childhood were those spent alone at home , circa 1925 .']},
#   'head_id': 4,
#   'head_word': 'hours',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Plur'},
#  {'sent_id': 14,
#   'all_syllables': 55,
#   'coordination': {'conj_id': [13, 40],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [15, 30, 8],
#    'parts_tokens': [12, 26, 4],
#    'coordination_text_parts': ['My parents would be working in their clothing store , my brother ',
#     'sister would be in school , , tucked in their 1910 Grand Rapids mahogany bed between two billowy white sheets , listening to Farrar sing Gilda ',
#     'reading the encyclopedia .']},
#   'head_id': 5,
#   'head_word': 'working',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Pres|VerbForm=Part'},
#  {'sent_id': 15,
#   'all_syllables': 35,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [35],
#    'parts_tokens': [27],
#    'coordination_text_parts': ['I have little doubt that more than half of what I know today I learned from the pages of the Ninth Edition of the Encyclopaedia Britannica .']},
#   'head_id': 2,
#   'head_word': 'have',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 16,
#   'all_syllables': 22,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [22],
#    'parts_tokens': [15],
#    'coordination_text_parts': ['I suspect that this accounts for my essentially nineteenth - century ideas about science .']},
#   'head_id': 2,
#   'head_word': 'suspect',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 17,
#   'all_syllables': 85,
#   'coordination': {'conj_id': [1, 7, 13, 15, 42, 62, 70],
#    'conj_word': ['And', 'and', 'or', 'or', 'or', 'either', 'or'],
#    'parts_syllables': [0, 7, 6, 2, 29, 22, 5, 6],
#    'parts_tokens': [0, 5, 5, 1, 26, 19, 7, 5],
#    'coordination_text_parts': ['',
#     'I muse that my frenetic ',
#     'nervous way of studying ( ',
#     'reading ',
#     'writing ) -- a lifelong habit -- could well be a happy remnant of the fact that my first earnest perusals of " The Geometry " ',
#     '" Kant " were interrupted every few minutes by the need to leap out of my parents \' bed ',
#     'to change the 78 - rpm record ',
#     'to wind the Victrola .']},
#   'head_id': 3,
#   'head_word': 'muse',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 18,
#   'all_syllables': 44,
#   'coordination': {'conj_id': [28],
#    'conj_word': ['and'],
#    'parts_syllables': [39, 4],
#    'parts_tokens': [27, 3],
#    'coordination_text_parts': ["It seems unlikely that I would so deeply love the intellectual life today had I not initially found my young mind 's independence within such a cozy ",
#     'easeful setting .']},
#   'head_id': 2,
#   'head_word': 'seems',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 19,
#   'all_syllables': 35,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [35],
#    'parts_tokens': [29],
#    'coordination_text_parts': ["Fast - forward to 1949 , the year that , quite by accident , I met my life 's second great strand at the Brentwood Veterans Administration hospital ."]},
#   'head_id': 3,
#   'head_word': 'forward',
#   'head_tag': 'ADV',
#   'governor.ms': ' '},
#  {'sent_id': 20,
#   'all_syllables': 46,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [46],
#    'parts_tokens': [35],
#    'coordination_text_parts': ["On that particular morning I was in the subbasement of the old Los Angeles Hall of Records , in the coroner 's vault , looking at file folders containing the records of certified deaths ."]},
#   'head_id': 9,
#   'head_word': 'subbasement',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 21,
#   'all_syllables': 42,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [42],
#    'parts_tokens': [27],
#    'coordination_text_parts': ['The director of my hospital had asked me to prepare letters to two young widows whose husbands had recently committed suicide while they were hospital patients .']},
#   'head_id': 7,
#   'head_word': 'asked',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part'},
#  {'sent_id': 22,
#   'all_syllables': 21,
#   'coordination': {'conj_id': [17],
#    'conj_word': ['and'],
#    'parts_syllables': [16, 4],
#    'parts_tokens': [16, 5],
#    'coordination_text_parts': ["My intention was to look at the two men 's folders , make some notes , ",
#     'get back to work .']},
#   'head_id': 3,
#   'head_word': 'was',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 23,
#   'all_syllables': 20,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [20],
#    'parts_tokens': [16],
#    'coordination_text_parts': ['The first folder contained something I had not seen before : a genuine suicide note .']},
#   'head_id': 4,
#   'head_word': 'contained',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 24,
#   'all_syllables': 7,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [7],
#    'parts_tokens': [6],
#    'coordination_text_parts': ['The second folder did not .']},
#   'head_id': 4,
#   'head_word': 'did',
#   'head_tag': 'AUX',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 25,
#   'all_syllables': 6,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [6],
#    'parts_tokens': [7],
#    'coordination_text_parts': ['Who could stop at this point ? ']},
#   'head_id': 3,
#   'head_word': 'stop',
#   'head_tag': 'VERB',
#   'governor.ms': 'VerbForm=Inf'},
#  {'sent_id': 26,
#   'all_syllables': 9,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [9],
#    'parts_tokens': [7],
#    'coordination_text_parts': ['I looked at several dozen folders .']},
#   'head_id': 2,
#   'head_word': 'looked',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 27,
#   'all_syllables': 32,
#   'coordination': {'conj_id': [22],
#    'conj_word': ['and'],
#    'parts_syllables': [26, 5],
#    'parts_tokens': [21, 5],
#    'coordination_text_parts': ['It seemed that every so often I would open a folder -- about one out of every fifteen suicide folders - ',
#     'find a suicide note .']},
#   'head_id': 2,
#   'head_word': 'seemed',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 28,
#   'all_syllables': 39,
#   'coordination': {'conj_id': [12],
#    'conj_word': ['and'],
#    'parts_syllables': [12, 26],
#    'parts_tokens': [11, 16],
#    'coordination_text_parts': ['I did a quick count of the folders on one shelf ',
#     'estimated that I was standing in a room that contained approximately two thousand suicide notes .']},
#   'head_id': 2,
#   'head_word': 'did',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 29,
#   'all_syllables': 28,
#   'coordination': {'conj_id': [12],
#    'conj_word': ['and'],
#    'parts_syllables': [13, 14],
#    'parts_tokens': [11, 12],
#    'coordination_text_parts': ['I felt like a cowpoke who , wandering home of oil ',
#     'is just sober enough to realize he has found his fortune .']},
#   'head_id': 2,
#   'head_word': 'felt',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 30,
#   'all_syllables': 61,
#   'coordination': {'conj_id': [31],
#    'conj_word': ['but'],
#    'parts_syllables': [36, 24],
#    'parts_tokens': [30, 20],
#    'coordination_text_parts': ["Had I indulged my initial urge to read the letters right there in the coroner 's vault , I might have learned a good deal about individual human tragedy , ",
#     'I would have done nothing to advance the study of suicide , which was then an almost nonexistent field .']},
#   'head_id': 22,
#   'head_word': 'learned',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part'},
#  {'sent_id': 31,
#   'all_syllables': 80,
#   'coordination': {'conj_id': [22, 36],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [28, 17, 33],
#    'parts_tokens': [21, 13, 23],
#    'coordination_text_parts': ['Instead , in a decision that changed my life , I made photocopies of more than seven hundred genuine suicide notes ',
#     'put them aside without reading them , so that my colleague Norman Farberow ',
#     'I could later compare them , in blind controlled studies , with simulated suicide notes that would be elicited from nonsuicidal people .']},
#   'head_id': 12,
#   'head_word': 'made',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 32,
#   'all_syllables': 31,
#   'coordination': {'conj_id': [11],
#    'conj_word': ['and'],
#    'parts_syllables': [11, 19],
#    'parts_tokens': [10, 10],
#    'coordination_text_parts': ['The result was the first work on suicide notes -- ',
#     'indirectly on suicide itself -- that followed scientific protocols .']},
#   'head_id': 6,
#   'head_word': 'work',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 33,
#   'all_syllables': 59,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [59],
#    'parts_tokens': [38],
#    'coordination_text_parts': ['My subsequent career -- helping to found the Los Angeles Suicide Prevention Center , developing a program in suicide prevention for the National Institute of Mental Health , thinking about suicide , writing about suicide -- all dates ']},
#   'head_id': 38,
#   'head_word': 'dates',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Plur'},
#  {'sent_id': 34,
#   'all_syllables': 38,
#   'coordination': {'conj_id': [17],
#    'conj_word': ['and'],
#    'parts_syllables': [23, 14],
#    'parts_tokens': [16, 13],
#    'coordination_text_parts': ['from that morning in the , I have been continuously intrigued by the topic of suicide ',
#     'drawn to people who are on the brink of serf - destruction .']},
#   'head_id': 11,
#   'head_word': 'intrigued',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 35,
#   'all_syllables': 31,
#   'coordination': {'conj_id': [18],
#    'conj_word': ['and'],
#    'parts_syllables': [24, 6],
#    'parts_tokens': [17, 3],
#    'coordination_text_parts': ['I am not a suicidal person myself ; my fascination is , I suppose , partly voyeuristic ',
#     'partly scientific .']},
#   'head_id': 6,
#   'head_word': 'person',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 36,
#   'all_syllables': 48,
#   'coordination': {'conj_id': [9, 29],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [12, 27, 7],
#    'parts_tokens': [8, 19, 4],
#    'coordination_text_parts': ['I have always been attracted to excitement , ',
#     'few things could be more exciting than the pursuit of understanding in a virgin field that involved such strong ',
#     'intimate human emotions .']},
#   'head_id': 5,
#   'head_word': 'attracted',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 37,
#   'all_syllables': 85,
#   'coordination': {'conj_id': [65],
#    'conj_word': ['and'],
#    'parts_syllables': [81, 3],
#    'parts_tokens': [64, 2],
#    'coordination_text_parts': ['The reader can surmise what it meant to me , a quarter century after I happened upon those suicide notes , to be invited to contribute my own seven pages of printed text , headed " Suicide , " to volume 21 of the 1973 edition of the Encyclopaedia Britannica , the same set of books that once was my Testament , Koran , ',
#     'Upanishads .']},
#   'head_id': 4,
#   'head_word': 'surmise',
#   'head_tag': 'VERB',
#   'governor.ms': 'VerbForm=Inf'},
#  {'sent_id': 38,
#   'all_syllables': 33,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [33],
#    'parts_tokens': [23],
#    'coordination_text_parts': ['I have come close to implying that the Ninth Edition of the Encyclopaedia Britannica was a kind of father figure to me .']},
#   'head_id': 3,
#   'head_word': 'come',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part'},
#  {'sent_id': 39,
#   'all_syllables': 29,
#   'coordination': {'conj_id': [9],
#    'conj_word': ['and'],
#    'parts_syllables': [9, 19],
#    'parts_tokens': [8, 14],
#    'coordination_text_parts': ['It is true that I treated those books ',
#     'the information in them with a respect bordering on awe , that cathedra .']},
#   'head_id': 3,
#   'head_word': 'true',
#   'head_tag': 'ADJ',
#   'governor.ms': 'Degree=Pos'},
#  {'sent_id': 40,
#   'all_syllables': 25,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [25],
#    'parts_tokens': [18],
#    'coordination_text_parts': ['At that time , all these sentiments were also true of my unquestioned attitudes toward my father .']},
#   'head_id': 10,
#   'head_word': 'true',
#   'head_tag': 'ADJ',
#   'governor.ms': 'Degree=Pos'},
#  {'sent_id': 41,
#   'all_syllables': 27,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [27],
#    'parts_tokens': [21],
#    'coordination_text_parts': ['Writing my own article for the EB was a psychological landmark ; it gave me a voice of my own .']},
#   'head_id': 11,
#   'head_word': 'landmark',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 42,
#   'all_syllables': 46,
#   'coordination': {'conj_id': [28, 30],
#    'conj_word': ['either', 'or'],
#    'parts_syllables': [36, 3, 4],
#    'parts_tokens': [27, 1, 3],
#    'coordination_text_parts': ['I suddenly felt like Ernest Pontifex , in The Way of All Flesh , who was finally able to contravene his father without feeling that he was ',
#     'destroying ',
#     'betraying him .']},
#   'head_id': 3,
#   'head_word': 'felt',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 43,
#   'all_syllables': 18,
#   'coordination': {'conj_id': [12],
#    'conj_word': ['or'],
#    'parts_syllables': [12, 5],
#    'parts_tokens': [11, 4],
#    'coordination_text_parts': ['Before I wrote my 1973 article , I looked at two ',
#     'three earlier pieces .']},
#   'head_id': 9,
#   'head_word': 'looked',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 44,
#   'all_syllables': 65,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [65],
#    'parts_tokens': [45],
#    'coordination_text_parts': ["It did not occur to me then to view them as documents of intellectual history ; I merely wished to identify my predecessors ' pitfalls -- such as an overreliance on dreary tables of statistics -- so I could avoid stepping into them myself ."]},
#   'head_id': 4,
#   'head_word': 'occur',
#   'head_tag': 'VERB',
#   'governor.ms': 'VerbForm=Inf'},
#  {'sent_id': 45,
#   'all_syllables': 46,
#   'coordination': {'conj_id': [5],
#    'conj_word': ['and'],
#    'parts_syllables': [6, 39],
#    'parts_tokens': [4, 27],
#    'coordination_text_parts': ['I wrote the article ',
#     'proudly added the Fourteenth Edition of the Britannica to the Ninth Edition that still reposed in the glass - fronted Stickley bookcase that I had inherited .']},
#   'head_id': 2,
#   'head_word': 'wrote',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 46,
#   'all_syllables': 6,
#   'coordination': {'conj_id': [2],
#    'conj_word': ['and'],
#    'parts_syllables': [1, 4],
#    'parts_tokens': [1, 5],
#    'coordination_text_parts': ['Two ', 'a half decades passed .']},
#   'head_id': 6,
#   'head_word': 'passed',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 47,
#   'all_syllables': 15,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [15],
#    'parts_tokens': [15],
#    'coordination_text_parts': ['Then , as I approached the age of eighty , I had another thought .']},
#   'head_id': 12,
#   'head_word': 'had',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 48,
#   'all_syllables': 29,
#   'coordination': {'conj_id': [10],
#    'conj_word': ['or'],
#    'parts_syllables': [11, 17],
#    'parts_tokens': [9, 15],
#    'coordination_text_parts': ["It was unlikely to have in one 's twenties ",
#     'even fifties , when the habit of looking back is not so fully developed .']},
#   'head_id': 3,
#   'head_word': 'unlikely',
#   'head_tag': 'ADJ',
#   'governor.ms': 'Degree=Pos'},
#  {'sent_id': 49,
#   'all_syllables': 22,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [22],
#    'parts_tokens': [19],
#    'coordination_text_parts': ['Why not examine the articles on suicide in all the editions since the first one , in 1768 ? ']},
#   'head_id': 3,
#   'head_word': 'examine',
#   'head_tag': 'VERB',
#   'governor.ms': 'VerbForm=Inf'},
#  {'sent_id': 50,
#   'all_syllables': 85,
#   'coordination': {'conj_id': [32, 45],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [40, 16, 27],
#    'parts_tokens': [31, 12, 23],
#    'coordination_text_parts': ["The idea allowed me simultaneously to become , all over again , the unformed child in a soft bed who had learned about the world from his parents ' encyclopedia , ",
#     'also to read these articles on suicide -- including my own -- ',
#     'see , from the emancipated vantage point of old age , their flaws , their anachronisms , their generational gaps of knowledge .']},
#   'head_id': 3,
#   'head_word': 'allowed',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 51,
#   'all_syllables': 76,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [76],
#    'parts_tokens': [48],
#    'coordination_text_parts': ["If the Britannica was the most authoritative popular repository of knowledge during the various eras of its existence , would not its successive treatments of suicide reflect , in a long chronological march , our culture 's changing attitudes toward the subject that had consumed my life ? "]},
#   'head_id': 27,
#   'head_word': 'reflect',
#   'head_tag': 'VERB',
#   'governor.ms': 'VerbForm=Inf'},
#  {'sent_id': 52,
#   'all_syllables': 59,
#   'coordination': {'conj_id': [18],
#    'conj_word': ['and'],
#    'parts_syllables': [18, 40],
#    'parts_tokens': [17, 33],
#    'coordination_text_parts': ['With the help of the Chicago staff of the EB , the New York Public Library , ',
#     "Harvard 's Houghton Library , I assembled copies of the encyclopedia 's fourteen story -- the attempt , over time , to answer such crucial questions as : Is suicide a sin ? "]},
#   'head_id': 25,
#   'head_word': 'assembled',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 53,
#   'all_syllables': 4,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [4],
#    'parts_tokens': [5],
#    'coordination_text_parts': ['Is it a crime ? ']},
#   'head_id': 4,
#   'head_word': 'crime',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 54,
#   'all_syllables': 21,
#   'coordination': {'conj_id': [8],
#    'conj_word': ['or'],
#    'parts_syllables': [16, 4],
#    'parts_tokens': [7, 3],
#    'coordination_text_parts': ['Is it the responsibility of the individual ',
#     'of society ? ']},
#   'head_id': 4,
#   'head_word': 'responsibility',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 55,
#   'all_syllables': 4,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [4],
#    'parts_tokens': [4],
#    'coordination_text_parts': ['What causes it ? ']},
#   'head_id': 2,
#   'head_word': 'causes',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 56,
#   'all_syllables': 13,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [13],
#    'parts_tokens': [8],
#    'coordination_text_parts': ['Can human suffering be reduced to statistics ? ']},
#   'head_id': 5,
#   'head_word': 'reduced',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 57,
#   'all_syllables': 8,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [8],
#    'parts_tokens': [6],
#    'coordination_text_parts': ['How can suicide be prevented ? ']},
#   'head_id': 5,
#   'head_word': 'prevented',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 58,
#   'all_syllables': 6,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [6],
#    'parts_tokens': [5],
#    'coordination_text_parts': ['Should it be prevented ? ']},
#   'head_id': 4,
#   'head_word': 'prevented',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 59,
#   'all_syllables': 23,
#   'coordination': {'conj_id': [1],
#    'conj_word': ['And'],
#    'parts_syllables': [0, 22],
#    'parts_tokens': [0, 21],
#    'coordination_text_parts': ['',
#     "that story is what is now spread out , with my wife 's indulgence , all over our dining table ."]},
#   'head_id': 5,
#   'head_word': 'what',
#   'head_tag': 'PRON',
#   'governor.ms': 'PronType=Int'},
#  {'sent_id': 60,
#   'all_syllables': 69,
#   'coordination': {'conj_id': [25, 30, 46],
#    'conj_word': ['et', 'and', 'and'],
#    'parts_syllables': [44, 4, 17, 4],
#    'parts_tokens': [24, 4, 15, 2],
#    'coordination_text_parts': ['The Encyclopaedia Britannica , while not the first encyclopedia -- its forerunners include the remarkable Encyclopedie ou Dictionnaire raisonne des Sciences , des Arts ',
#     'des Metiers of Diderot ',
#     "d' Alembert , published in France starting in 1751 -- has remained the most constant ",
#     'influential .']},
#   'head_id': 42,
#   'head_word': 'remained',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part'},
#  {'sent_id': 61,
#   'all_syllables': 12,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [12],
#    'parts_tokens': [10],
#    'coordination_text_parts': ['Its first edition was published in Edinburgh in 1768 .']},
#   'head_id': 5,
#   'head_word': 'published',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 62,
#   'all_syllables': 27,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [27],
#    'parts_tokens': [23],
#    'coordination_text_parts': ['There have been fourteen editions since then , of which the Eleventh Edition , of 1910 , is generally considered the greatest .']},
#   'head_id': 3,
#   'head_word': 'been',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part'},
#  {'sent_id': 63,
#   'all_syllables': 74,
#   'coordination': {'conj_id': [11],
#    'conj_word': ['or'],
#    'parts_syllables': [14, 59],
#    'parts_tokens': [10, 40],
#    'coordination_text_parts': ['Roughly speaking , a new edition was published every ten ',
#     'twenty years ( in the interim there were sometimes several printings with minor variations ) until the a half century , there were only relatively modest alterations : some articles were dropped , some added , some contributors replaced .']},
#   'head_id': 8,
#   'head_word': 'published',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 64,
#   'all_syllables': 85,
#   'coordination': {'conj_id': [59],
#    'conj_word': ['and'],
#    'parts_syllables': [75, 10],
#    'parts_tokens': [58, 9],
#    'coordination_text_parts': ['With the Fifteenth Edition , in 1974 , there was a radical restructuring of the overall format of the EB : the time honored , strictly alphabetical arrangement was dropped in favor of a thesaurus - like approach , including a one - volume Propaedia ( an overview ) , a Micropaedia ( a comprehensive survey ) , ',
#     'a Macropaedia ( topics discussed in detail ) .']},
#   'head_id': 10,
#   'head_word': 'was',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 65,
#   'all_syllables': 30,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [30],
#    'parts_tokens': [30],
#    'coordination_text_parts': ['The latest version of the Britannica , " published " in 1994 , is on CD - ROM -- a hundred pounds of books reduced to about an ounce .']},
#   'head_id': 18,
#   'head_word': 'ROM',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 66,
#   'all_syllables': 24,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [24],
#    'parts_tokens': [15],
#    'coordination_text_parts': ['There was no article on suicide in the first edition of the Encyclopaedia Britannica .']},
#   'head_id': 2,
#   'head_word': 'was',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 67,
#   'all_syllables': 14,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [14],
#    'parts_tokens': [11],
#    'coordination_text_parts': ['That is understandable ; the word itself was fairly new .']},
#   'head_id': 3,
#   'head_word': 'understandable',
#   'head_tag': 'ADJ',
#   'governor.ms': 'Degree=Pos'},
#  {'sent_id': 68,
#   'all_syllables': 27,
#   'coordination': {'conj_id': [5, 13],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [4, 13, 8],
#    'parts_tokens': [4, 7, 6],
#    'coordination_text_parts': ['( The words suicide ',
#     'encyclopedia seem to have a common vintage ',
#     'perhaps even a common creator .']},
#   'head_id': 7,
#   'head_word': 'seem',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 69,
#   'all_syllables': 63,
#   'coordination': {'conj_id': [15],
#    'conj_word': ['and'],
#    'parts_syllables': [18, 44],
#    'parts_tokens': [14, 35],
#    'coordination_text_parts': ['The vintage is the fifth decade of the seventeenth century , 1642 for suicide ',
#     '1646 for encyclopedia ; the creator is Sir Thomas Browne , the author of Religio Second Edition of the EB was published , it contained a memorable article called " Self - Murder ." ']},
#   'head_id': 6,
#   'head_word': 'decade',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 70,
#   'all_syllables': 7,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [7],
#    'parts_tokens': [10],
#    'coordination_text_parts': ['" Self - Murder " is one page long .']},
#   'head_id': 9,
#   'head_word': 'long',
#   'head_tag': 'ADJ',
#   'governor.ms': 'Degree=Pos'},
#  {'sent_id': 71,
#   'all_syllables': 13,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [13],
#    'parts_tokens': [13],
#    'coordination_text_parts': ['Whatever else can be said about it , it is not dull .']},
#   'head_id': 12,
#   'head_word': 'dull',
#   'head_tag': 'ADJ',
#   'governor.ms': 'Degree=Pos'},
#  {'sent_id': 72,
#   'all_syllables': 41,
#   'coordination': {'conj_id': [11, 18],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [11, 7, 21],
#    'parts_tokens': [10, 6, 16],
#    'coordination_text_parts': ['It jerks you awake with the first sentence , hectors ',
#     'shakes you until the finish , ',
#     ', at the very end , makes an unconvincing attempt to soften its Draconian stance .']},
#   'head_id': 2,
#   'head_word': 'jerks',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 73,
#   'all_syllables': 22,
#   'coordination': {'conj_id': [7],
#    'conj_word': ['and'],
#    'parts_syllables': [6, 15],
#    'parts_tokens': [6, 12],
#    'coordination_text_parts': ['It has the smell of fire ',
#     'brimstone , the sound of a wrathful sermon by Cotton Mather .']},
#   'head_id': 2,
#   'head_word': 'has',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 74,
#   'all_syllables': 107,
#   'coordination': {'conj_id': [8, 22, 60],
#    'conj_word': ['but', 'but', 'yet'],
#    'parts_syllables': [14, 19, 47, 24],
#    'parts_tokens': [7, 13, 37, 18],
#    'coordination_text_parts': ['The article begins with a beautifully expressed ',
#     'horrendously cruel definition : " SELF - MURDER , the pretended heroism , ',
#     'real cowardice , of the Stoic philosophers , who destroyed themselves to avoid those ills which they had not the fortitude to endure , though the attempting it seems to be countenanced by the civil law , ',
#     'was punished by the Athenian law with cutting off the hand which committed the desperate deed ." ']},
#   'head_id': 3,
#   'head_word': 'begins',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 75,
#   'all_syllables': 17,
#   'coordination': {'conj_id': [10],
#    'conj_word': ['and'],
#    'parts_syllables': [13, 3],
#    'parts_tokens': [9, 3],
#    'coordination_text_parts': ['It continues in a vein that joins the religious ',
#     'the legal : ']},
#   'head_id': 2,
#   'head_word': 'continues',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 76,
#   'all_syllables': 127,
#   'coordination': {'conj_id': [1, 11, 16, 22, 44],
#    'conj_word': ['And', 'but', 'and', 'and', 'and'],
#    'parts_syllables': [0, 13, 6, 5, 29, 69],
#    'parts_tokens': [0, 9, 4, 5, 21, 55],
#    'coordination_text_parts': ['',
#     'also the law of England wisely to destroy life ',
#     'by commission from God ',
#     'the author of it ; ',
#     'as the suicide is guilty of a double offence ; one spiritual , in invading the prerogative of the Almighty , ',
#     "rushing into his immediate presence uncalled for ; the other temporal , against the king , who hath an interest in the preservation of all his subjects ; the law has therefore ranked this among the highest crimes , making it a peculiar species of felony ; a felony committed on one 's self ."]},
#   'head_id': 4,
#   'head_word': 'law',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 77,
#   'all_syllables': 28,
#   'coordination': {'conj_id': [1],
#    'conj_word': ['And'],
#    'parts_syllables': [0, 27],
#    'parts_tokens': [0, 23],
#    'coordination_text_parts': ['',
#     'it concludes with an answer to the obvious question : If the felon is dead , how can human laws punish him ? ']},
#   'head_id': 3,
#   'head_word': 'concludes',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 78,
#   'all_syllables': 92,
#   'coordination': {'conj_id': [15, 38, 49, 60, 64],
#    'conj_word': ['and', 'or', 'and', 'either', 'or'],
#    'parts_syllables': [19, 26, 12, 11, 6, 12],
#    'parts_tokens': [14, 22, 10, 10, 3, 10],
#    'coordination_text_parts': ['They can only act upon what he has left behind him , his reputation ',
#     'fortune ; on the former , by an ignominious burial in the highway , with a stake driven through his body ; ',
#     'the latter , by a forfeiture of all his goods ',
#     'chattels to the king , hoping that his care for ',
#     'his own reputation ',
#     'the welfare of his family would be some act . . . . ']},
#   'head_id': 4,
#   'head_word': 'act',
#   'head_tag': 'VERB',
#   'governor.ms': 'VerbForm=Inf'},
#  {'sent_id': 79,
#   'all_syllables': 84,
#   'coordination': {'conj_id': [1, 20],
#    'conj_word': ['And', 'yet'],
#    'parts_syllables': [0, 23, 59],
#    'parts_tokens': [0, 18, 44],
#    'coordination_text_parts': ['',
#     "tho ' it must be owned that the letter of the law herein borders a little on severity ; ",
#     'it is some alleviation , that the power of mitigation is left in the breast of the sovereign , who upon this ( as on all other occasions ) is reminded by the oath of his office , to execute judgment in mercy .']},
#   'head_id': 6,
#   'head_word': 'owned',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 80,
#   'all_syllables': 23,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [23],
#    'parts_tokens': [17],
#    'coordination_text_parts': ["The last sentence strikes me as conveying the same dubious comfort as a hangman 's blessing ."]},
#   'head_id': 4,
#   'head_word': 'strikes',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 81,
#   'all_syllables': 85,
#   'coordination': {'conj_id': [38],
#    'conj_word': ['and'],
#    'parts_syllables': [53, 31],
#    'parts_tokens': [37, 20],
#    'coordination_text_parts': ["The anonymous author of this mean - spirited little article -- whose only mention of prevention is its approving note on the custom , prevalent at the time , of besmirching the self - murderer 's reputation ",
#     'confiscating his worldly goods -- is clearly far more interested in flagellating the suicide than in keeping him alive .']},
#   'head_id': 48,
#   'head_word': 'interested',
#   'head_tag': 'ADJ',
#   'governor.ms': 'Degree=Pos'},
#  {'sent_id': 82,
#   'all_syllables': 31,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [31],
#    'parts_tokens': [24],
#    'coordination_text_parts': ["By 1788 , when the Third Edition was published , the word suicide had gained sufficient currency to constitute the article 's title ."]},
#   'head_id': 15,
#   'head_word': 'gained',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part'},
#  {'sent_id': 83,
#   'all_syllables': 78,
#   'coordination': {'conj_id': [1, 22, 25, 70],
#    'conj_word': ['And', 'and', 'or', 'and'],
#    'parts_syllables': [0, 18, 1, 53, 2],
#    'parts_tokens': [0, 20, 2, 44, 2],
#    'coordination_text_parts': ['',
#     "this time the EB had much more to say : five pages ' worth , starting with a far briefer ",
#     'more , ',
#     'the person who commits it ." The first section of the article is a historical survey of suicide among the Jews , the ancient Greeks , the Brahmins , the Hindus , the Japanese , the Scythians , the tribes of Scandinavia , ',
#     'others .']},
#   'head_id': 6,
#   'head_word': 'had',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 84,
#   'all_syllables': 20,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [20],
#    'parts_tokens': [17],
#    'coordination_text_parts': ['The tone of this report can be gathered from the paragraph on suicide among the Jews : ']},
#   'head_id': 8,
#   'head_word': 'gathered',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 85,
#   'all_syllables': 22,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [22],
#    'parts_tokens': [18],
#    'coordination_text_parts': ['Suicide is one of those crimes which we are led to believe not common among savage nations .']},
#   'head_id': 3,
#   'head_word': 'one',
#   'head_tag': 'NUM',
#   'governor.ms': 'NumType=Card'},
#  {'sent_id': 86,
#   'all_syllables': 38,
#   'coordination': {'conj_id': [15, 18],
#    'conj_word': ['and', 'for'],
#    'parts_syllables': [19, 2, 15],
#    'parts_tokens': [14, 2, 12],
#    'coordination_text_parts': ['The first instances of it recorded in the Jewish history are those of Saul ',
#     'Ahitophel ; ',
#     'we do not think the death of Samson a proper example .']},
#   'head_id': 12,
#   'head_word': 'those',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Plur'},
#  {'sent_id': 87,
#   'all_syllables': 46,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [46],
#    'parts_tokens': [36],
#    'coordination_text_parts': ['We have no reason to suppose it became common among the Jews till their wars with the Romans , when multitudes slaughtered themselves that they might not fall alive into the hands of their enemies .']},
#   'head_id': 2,
#   'head_word': 'have',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 88,
#   'all_syllables': 52,
#   'coordination': {'conj_id': [1, 11, 25],
#    'conj_word': ['But', 'and', 'and'],
#    'parts_syllables': [0, 13, 17, 19],
#    'parts_tokens': [0, 9, 13, 14],
#    'coordination_text_parts': ['',
#     'at this period the Jews were a most desperate ',
#     'abandoned race of men , had corrupted the religion of their fathers , ',
#     'rejected that pure system which their promised Messiah came to Jerusalem to announce .']},
#   'head_id': 13,
#   'head_word': 'race',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 89,
#   'all_syllables': 2,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [2],
#    'parts_tokens': [3],
#    'coordination_text_parts': ['until 1852 .']},
#   'head_id': 2,
#   'head_word': '1852',
#   'head_tag': 'NUM',
#   'governor.ms': 'NumType=Card'},
#  {'sent_id': 90,
#   'all_syllables': 57,
#   'coordination': {'conj_id': [31, 35],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [37, 2, 16],
#    'parts_tokens': [30, 3, 13],
#    'coordination_text_parts': ['As for the causes of suicide in England , they are ascribed to " the variableness of the climate , the great use of animal food , strong spiritous liquors ',
#     'to tea , ',
#     'to the sulphurous exhalations of the pit - coal used as fuel . . . . ']},
#   'head_id': 12,
#   'head_word': 'ascribed',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 91,
#   'all_syllables': 56,
#   'coordination': {'conj_id': [17, 28],
#    'conj_word': ['for', 'and'],
#    'parts_syllables': [19, 11, 24],
#    'parts_tokens': [16, 10, 20],
#    'coordination_text_parts': ['We are rather surprised that coal is mentioned even as a distant cause of suicide , ',
#     'it is one of the blessings of our island ; ',
#     'a good coal fire we have always found rather conducive to good spirits rather than injurious to them ." ']},
#   'head_id': 4,
#   'head_word': 'surprised',
#   'head_tag': 'ADJ',
#   'governor.ms': 'Degree=Pos'},
#  {'sent_id': 92,
#   'all_syllables': 17,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [17],
#    'parts_tokens': [17],
#    'coordination_text_parts': ['It is rare to find such a cozy passage in the staid pages of the EB .']},
#   'head_id': 3,
#   'head_word': 'rare',
#   'head_tag': 'ADJ',
#   'governor.ms': 'Degree=Pos'},
#  {'sent_id': 93,
#   'all_syllables': 49,
#   'coordination': {'conj_id': [5, 27],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [8, 32, 7],
#    'parts_tokens': [4, 21, 4],
#    'coordination_text_parts': ['Having disposed of history ',
#     'causation , the article moves on to the aspects that had constituted the entirety of the 1777 article : the morality ',
#     'legality of suicide .']},
#   'head_id': 10,
#   'head_word': 'moves',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 94,
#   'all_syllables': 24,
#   'coordination': {'conj_id': [21],
#    'conj_word': ['and'],
#    'parts_syllables': [21, 2],
#    'parts_tokens': [20, 3],
#    'coordination_text_parts': ['It reasserts that suicide is a felo - de-se ( a felony against oneself ) , a crime against God ',
#     'the king .']},
#   'head_id': 2,
#   'head_word': 'reasserts',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 95,
#   'all_syllables': 77,
#   'coordination': {'conj_id': [1, 45],
#    'conj_word': ['But', 'and'],
#    'parts_syllables': [0, 57, 18],
#    'parts_tokens': [0, 43, 18],
#    'coordination_text_parts': ['',
#     'it ends with a sentence that indicates that the times are changing : " Suicide , we it is a difficult matter to find an effectual remedy . . . . Punishment will not be a preventive , even if it could be always inflicted ; ',
#     'that it is seldom inflicted , though the laws have decreed it , is well known ." ']},
#   'head_id': 3,
#   'head_word': 'ends',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 96,
#   'all_syllables': 34,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [34],
#    'parts_tokens': [19],
#    'coordination_text_parts': ['This Concluding emphasis on prevention , complete with a humble acknowledgment of its difficulty , sounds surprisingly modern .']},
#   'head_id': 16,
#   'head_word': 'sounds',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 97,
#   'all_syllables': 34,
#   'coordination': {'conj_id': [32],
#    'conj_word': ['and'],
#    'parts_syllables': [29, 4],
#    'parts_tokens': [31, 6],
#    'coordination_text_parts': ['The historical portions of this entry appeared essentially unchanged for sixty - four years in the Fourth ( 1801 ) , Fifth ( 1815 ) , Sixth ( 1820 ) , ',
#     'Seventh ( 1830 ) Editions .']},
#   'head_id': 7,
#   'head_word': 'appeared',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 98,
#   'all_syllables': 5,
#   'coordination': {'conj_id': [1],
#    'conj_word': ['But'],
#    'parts_syllables': [0, 4],
#    'parts_tokens': [0, 4],
#    'coordination_text_parts': ['', 'changes were coming .']},
#   'head_id': 4,
#   'head_word': 'coming',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Pres|VerbForm=Part'},
#  {'sent_id': 99,
#   'all_syllables': 23,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [23],
#    'parts_tokens': [25],
#    'coordination_text_parts': ['The entry for " Suicide " in the Eighth Edition ( 1852 - 1860 ) in many ways repeats the contents of the Seventh .']},
#   'head_id': 19,
#   'head_word': 'repeats',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 100,
#   'all_syllables': 32,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [32],
#    'parts_tokens': [18],
#    'coordination_text_parts': ['However , it is notable for including landmark quotations from two major nineteenth - century intellectual figures .']},
#   'head_id': 5,
#   'head_word': 'notable',
#   'head_tag': 'ADJ',
#   'governor.ms': 'Degree=Pos'},
#  {'sent_id': 101,
#   'all_syllables': 28,
#   'coordination': {'conj_id': [12],
#    'conj_word': ['and'],
#    'parts_syllables': [15, 12],
#    'parts_tokens': [11, 4],
#    'coordination_text_parts': ['The first quotation is from Henry Thomas Buckle , chess prodigy ',
#     'scientifically minded historian .']},
#   'head_id': 6,
#   'head_word': 'Henry',
#   'head_tag': 'PROPN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 102,
#   'all_syllables': 51,
#   'coordination': {'conj_id': [27],
#    'conj_word': ['and'],
#    'parts_syllables': [38, 12],
#    'parts_tokens': [26, 10],
#    'coordination_text_parts': ['Buckle believes that " the progress of every people is regulated by principles . . . as certain as those which govern the physical suicide rates over years ',
#     'points to the folly of enacting laws against it .']},
# ...
#     ', in the other , by securing the property right - ',
#     'as James Madison put it in the celebrated Tenth Federalist , by ." ']},
#   'head_id': 2,
#   'head_word': 'was',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 643,
#   'all_syllables': 18,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [18],
#    'parts_tokens': [18],
#    'coordination_text_parts': ['He went so far as to say that this was " the first object " of government .']},
#   'head_id': 2,
#   'head_word': 'went',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 644,
#   'all_syllables': 45,
#   'coordination': {'conj_id': [18, 21],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [29, 3, 11],
#    'parts_tokens': [17, 2, 10],
#    'coordination_text_parts': ['To repeat : guided by the new political philosophy , we established a commercial republic , peaceful ',
#     'prosperous , ',
#     'peaceful , in part , because it is prosperous .']},
#   'head_id': 12,
#   'head_word': 'established',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 645,
#   'all_syllables': 22,
#   'coordination': {'conj_id': [13],
#    'conj_word': ['or'],
#    'parts_syllables': [16, 5],
#    'parts_tokens': [12, 6],
#    'coordination_text_parts': ['The Constitution secures our rights , including the right to be - ',
#     'not to be - cultured .']},
#   'head_id': 3,
#   'head_word': 'secures',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 646,
#   'all_syllables': 4,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [4],
#    'parts_tokens': [5],
#    'coordination_text_parts': ['The choice is ours .']},
#   'head_id': 4,
#   'head_word': 'ours',
#   'head_tag': 'PRON',
#   'governor.ms': ' '},
#  {'sent_id': 647,
#   'all_syllables': 71,
#   'coordination': {'conj_id': [17, 29, 44],
#    'conj_word': ['and', 'or', 'or'],
#    'parts_syllables': [15, 11, 14, 28],
#    'parts_tokens': [16, 11, 14, 28],
#    'coordination_text_parts': ['We can spend our leisure time reading the Bible , Petrarch , Dante , Shakespere , ',
#     'listening to the music of Bach , Mozart , Beethoven , ',
#     ', on the other hand , by going to the movies , watching MTV ',
#     ', thanks to modern science ( which is protected by the Constitution - see art . 1 , sec. 8 , cl. 8 ) gaping at internet porn .']},
#   'head_id': 3,
#   'head_word': 'spend',
#   'head_tag': 'VERB',
#   'governor.ms': 'VerbForm=Inf'},
#  {'sent_id': 648,
#   'all_syllables': 13,
#   'coordination': {'conj_id': [9],
#    'conj_word': ['or'],
#    'parts_syllables': [9, 3],
#    'parts_tokens': [8, 3],
#    'coordination_text_parts': ['We enjoy the right to do the one ',
#     'the other .']},
#   'head_id': 2,
#   'head_word': 'enjoy',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 649,
#   'all_syllables': 23,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [23],
#    'parts_tokens': [17],
#    'coordination_text_parts': ['As someone once said , the Constitution gives rights to vulgarity as well as to culture .']},
#   'head_id': 8,
#   'head_word': 'gives',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 650,
#   'all_syllables': 44,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [44],
#    'parts_tokens': [31],
#    'coordination_text_parts': ['What began in nineteenth - century Britain as a serious critique of the new liberal democracy became , in almost a way of life for some of our campus radicals .']},
#   'head_id': 17,
#   'head_word': 'became',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 651,
#   'all_syllables': 21,
#   'coordination': {'conj_id': [1],
#    'conj_word': ['But'],
#    'parts_syllables': [0, 20],
#    'parts_tokens': [0, 14],
#    'coordination_text_parts': ['',
#     'if not American liberal democracy , with all its vulgarity , then what ? ']},
#   'head_id': 14,
#   'head_word': 'what',
#   'head_tag': 'PRON',
#   'governor.ms': 'PronType=Int'},
#  {'sent_id': 652,
#   'all_syllables': 6,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [6],
#    'parts_tokens': [5],
#    'coordination_text_parts': ["What 's the alternative ? "]},
#   'head_id': 1,
#   'head_word': 'What',
#   'head_tag': 'PRON',
#   'governor.ms': 'PronType=Int'},
#  {'sent_id': 653,
#   'all_syllables': 67,
#   'coordination': {'conj_id': [17],
#    'conj_word': ['but'],
#    'parts_syllables': [22, 44],
#    'parts_tokens': [16, 33],
#    'coordination_text_parts': ['Our intellectuals might , with reason , prefer Parisian crme caramel to American apple pie , ',
#     "they can not , with reason , prefer Moscow 's Marxism to America 's liberal democracy , if only because Marxism suffered an un-Marxist - i.e. , unhistorical - death in Moscow ."]},
#   'head_id': 8,
#   'head_word': 'prefer',
#   'head_tag': 'VERB',
#   'governor.ms': 'VerbForm=Inf'},
#  {'sent_id': 654,
#   'all_syllables': 49,
#   'coordination': {'conj_id': [26],
#    'conj_word': ['and'],
#    'parts_syllables': [34, 14],
#    'parts_tokens': [25, 9],
#    'coordination_text_parts': ['Orwell , to get back to him , accused the intellectuals of his time of being unpolitical , of living in the world of ideas ',
#     'having " little contact with physical reality ." ']},
#   'head_id': 9,
#   'head_word': 'accused',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 655,
#   'all_syllables': 9,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [9],
#    'parts_tokens': [10],
#    'coordination_text_parts': ['The same might be said of some of ours : ']},
#   'head_id': 5,
#   'head_word': 'said',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 656,
#   'all_syllables': 70,
#   'coordination': {'conj_id': [10, 25, 39],
#    'conj_word': ['but', 'and', 'and'],
#    'parts_syllables': [13, 16, 20, 18],
#    'parts_tokens': [9, 14, 13, 15],
#    'coordination_text_parts': ['Martha Nussbaum , for example , a Harvard classicist ',
#     'now a professor of law , as well as of ethics , philosophy , ',
#     'divinity ( a veritable polymath ) , at the University of Chicago , ',
#     'author of the lead essay in a book entitled , For Love of Country .']},
#   'head_id': 9,
#   'head_word': 'classicist',
#   'head_tag': 'PROPN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 657,
#   'all_syllables': 10,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [10],
#    'parts_tokens': [10],
#    'coordination_text_parts': ['It ought to be titled For Love of Nowhere .']},
#   'head_id': 5,
#   'head_word': 'titled',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part|Voice=Pass'},
#  {'sent_id': 658,
#   'all_syllables': 45,
#   'coordination': {'conj_id': [29],
#    'conj_word': ['but'],
#    'parts_syllables': [34, 10],
#    'parts_tokens': [28, 12],
#    'coordination_text_parts': ['Nussbaum calls cosmopolitan education , according to which students should be taught that " they are , above all , " citizens not of the United States , ',
#     ', instead , " of a world of human beings ." ']},
#   'head_id': 2,
#   'head_word': 'calls',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 659,
#   'all_syllables': 35,
#   'coordination': {'conj_id': [22],
#    'conj_word': ['or'],
#    'parts_syllables': [28, 6],
#    'parts_tokens': [21, 5],
#    'coordination_text_parts': ['Patriotism , as we ordinarily understand it , is a problem , she thinks , because it leads to parochialism , ',
#     '" partisan loyalties ." ']},
#   'head_id': 14,
#   'head_word': 'thinks',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 660,
#   'all_syllables': 32,
#   'coordination': {'conj_id': [14],
#    'conj_word': ['and'],
#    'parts_syllables': [23, 8],
#    'parts_tokens': [13, 8],
#    'coordination_text_parts': ['" Only by making our fundamental allegiance to the world community of justice ',
#     'reason do we avoid these dangers ." ']},
#   'head_id': 18,
#   'head_word': 'avoid',
#   'head_tag': 'VERB',
#   'governor.ms': 'VerbForm=Inf'},
#  {'sent_id': 661,
#   'all_syllables': 0,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [0],
#    'parts_tokens': [1],
#    'coordination_text_parts': ['4 ']},
#   'head_id': 1,
#   'head_word': '4',
#   'head_tag': 'X',
#   'governor.ms': ' '},
#  {'sent_id': 662,
#   'all_syllables': 18,
#   'coordination': {'conj_id': [1],
#    'conj_word': ['But'],
#    'parts_syllables': [0, 17],
#    'parts_tokens': [0, 13],
#    'coordination_text_parts': ['',
#     'where is this world community to which we can pledge our allegiance ? ']},
#   'head_id': 2,
#   'head_word': 'where',
#   'head_tag': 'ADV',
#   'governor.ms': 'PronType=Int'},
#  {'sent_id': 663,
#   'all_syllables': 5,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [5],
#    'parts_tokens': [4],
#    'coordination_text_parts': ['The United Nations ? ']},
#   'head_id': 3,
#   'head_word': 'Nations',
#   'head_tag': 'PROPN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 664,
#   'all_syllables': 35,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [35],
#    'parts_tokens': [36],
#    'coordination_text_parts': ['In fact , of course , this country , however numerous its imperfections , is now , as Abraham Lincoln said it was in 1862 , " the last , best hope of earth ." ']},
#   'head_id': 32,
#   'head_word': 'hope',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Sing'},
#  {'sent_id': 665,
#   'all_syllables': 64,
#   'coordination': {'conj_id': [46],
#    'conj_word': ['but'],
#    'parts_syllables': [50, 12],
#    'parts_tokens': [45, 7],
#    'coordination_text_parts': ['It is this because the cause of justice , equality , tolerance , human rights , all the values Nussbaum favors , depends not on the so - called World Community - Iran , Iraq , Saudi Arabia , North Korea , China ? - ',
#     'absolutely on this country its enemies .']},
#   'head_id': 3,
#   'head_word': 'this',
#   'head_tag': 'PRON',
#   'governor.ms': 'Number=Sing|PronType=Dem'},
#  {'sent_id': 666,
#   'all_syllables': 30,
#   'coordination': {'conj_id': [7],
#    'conj_word': ['and'],
#    'parts_syllables': [10, 19],
#    'parts_tokens': [6, 12],
#    'coordination_text_parts': ['She fails to appreciate this country ',
#     'the fact that there is nothing narrowly partisan about its patriotism .']},
#   'head_id': 2,
#   'head_word': 'fails',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 667,
#   'all_syllables': 14,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [14],
#    'parts_tokens': [11],
#    'coordination_text_parts': ['Lincoln made this clear in his eulogy on Henry Clay .']},
#   'head_id': 2,
#   'head_word': 'made',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 668,
#   'all_syllables': 77,
#   'coordination': {'conj_id': [18, 27, 38, 51, 60],
#    'conj_word': ['but', 'and', 'and', 'and', 'and'],
#    'parts_syllables': [17, 10, 14, 16, 11, 4],
#    'parts_tokens': [17, 8, 10, 12, 8, 4],
#    'coordination_text_parts': ['Clay , he said , " loved his country partly because it was his own country , ',
#     'mostly because it was a free country ; ',
#     'he burned with a zeal for its advancement , prosperity ',
#     'glory , because he saw in such , the advancement , prosperity ',
#     'glory , of human liberty , human right ',
#     'human nature ." ']},
#   'head_id': 7,
#   'head_word': 'loved',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 669,
#   'all_syllables': 4,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [4],
#    'parts_tokens': [5],
#    'coordination_text_parts': ['( Emphasis added .) ']},
#   'head_id': 3,
#   'head_word': 'added',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 670,
#   'all_syllables': 25,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [25],
#    'parts_tokens': [20],
#    'coordination_text_parts': ['In closing , I refer to an article by John Judis in The New Republic some time last year .']},
#   'head_id': 5,
#   'head_word': 'refer',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Pres|VerbForm=Fin'},
#  {'sent_id': 671,
#   'all_syllables': 0,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [0],
#    'parts_tokens': [1],
#    'coordination_text_parts': ['5 ']},
#   'head_id': 1,
#   'head_word': '5',
#   'head_tag': 'X',
#   'governor.ms': ' '},
#  {'sent_id': 672,
#   'all_syllables': 79,
#   'coordination': {'conj_id': [13, 41],
#    'conj_word': ['and', 'and'],
#    'parts_syllables': [18, 40, 19],
#    'parts_tokens': [12, 27, 16],
#    'coordination_text_parts': ['He had attended a conference in New York City on " globalization ',
#     'independent politics , " sponsored by the Nation Institute , George Soros \'s Open Society Institute , the Carnegie Institute , Barnard College , Columbia University , ',
#     'the City University of New York - in a word , a conference of academics .']},
#   'head_id': 3,
#   'head_word': 'attended',
#   'head_tag': 'VERB',
#   'governor.ms': 'Tense=Past|VerbForm=Part'},
#  {'sent_id': 673,
#   'all_syllables': 32,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [32],
#    'parts_tokens': [26],
#    'coordination_text_parts': ['As one might expect in such a gathering , the speakers accused , generally , a place where no decent person would choose to live .']},
#   'head_id': 12,
#   'head_word': 'accused',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 674,
#   'all_syllables': 57,
#   'coordination': {'conj_id': [11],
#    'conj_word': ['or'],
#    'parts_syllables': [15, 41],
#    'parts_tokens': [10, 34],
#    'coordination_text_parts': ['Among the speakers was a professor of politics at one ',
#     'another branch of the University of California , who said the " two - party system is a sanctuary for middle - class , white - skin that is , bourgeois privilege ." ']},
#   'head_id': 3,
#   'head_word': 'speakers',
#   'head_tag': 'NOUN',
#   'governor.ms': 'Number=Plur'},
#  {'sent_id': 675,
#   'all_syllables': 26,
#   'coordination': {'conj_id': [],
#    'conj_word': [],
#    'parts_syllables': [26],
#    'parts_tokens': [20],
#    'coordination_text_parts': ['Not to be outdone , a female member of the audience repeatedly complained of " brown tap water ." ']},
#   'head_id': 13,
#   'head_word': 'complained',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 676,
#   'all_syllables': 77,
#   'coordination': {'conj_id': [15, 28, 62],
#    'conj_word': ['but', 'and', 'and'],
#    'parts_syllables': [18, 12, 34, 10],
#    'parts_tokens': [14, 12, 33, 14],
#    'coordination_text_parts': ["Judis said he had intended to stay for Ralph Nader 's luncheon address , ",
#     ', instead , packed his suitcase , headed for Penn Station , ',
#     'caught the first train back to his quiet home in the Washington suburbs where , he said , people think " white - skin privilege " is a kind of hand cream , ',
#     ', when faced with " brown tap water , " call the plumber .']},
#   'head_id': 2,
#   'head_word': 'said',
#   'head_tag': 'VERB',
#   'governor.ms': 'Mood=Ind|Tense=Past|VerbForm=Fin'},
#  {'sent_id': 677,
#   'all_syllables': 28,
#   'coordination': {'conj_id': [1, 13],
#    'conj_word': ['And', 'and'],
#    'parts_syllables': [0, 11, 15],
#    'parts_tokens': [0, 11, 14],
#    'coordination_text_parts': ['',
#     'also , I would add , where they love this country ',
#     ', when necessary , are prepared to take up arms in its defense .']},
#   'head_id': 6,
#   'head_word': 'add',
#   'head_tag': 'VERB',
#   'governor.ms': 'VerbForm=Inf'}]

# %%
conj_one_only = []
for infor in info["sentences"]:
    if len(infor["coordination"]["conj_id"]) == 1:
        conj_one_only.append(infor["sent_id"])

# %%
print(conj_one_only)

# %%
with open("connllu_conj_one.txt", "w") as file:
    for id_conj in conj_one_only:
        sentence = all["sentences"][id_conj-1]
        id = sentence["id"]
        text = sentence["text"]
        file.write(f"# sent_id = {id}\n")
        file.write(f"# text = {text}\n")

        for token in sentence["tokens"]:
            conllu_token = "{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}".format(
            token["id"],  # ID
            token["text"],  # FORM
            token["lemma"],  # LEMMA
            token["upos"],  # UPOS
            token["xpos"],  # XPOS
            "_",  # FEATS
            token["head"],  # HEAD
            token["deprel"],  # DEPREL
            "_",  # DEPS
            "_"  # MISC
            )
            file.write(f"{conllu_token}\n")
        
        file.write("\n")

# %% [markdown]
# ---

# %%
def create_rows_from_parser(parsed_dict, columns_info):
   df = columns_info
   sentences = parsed_dict["sentences"]
   for sentence in sentences:
      list = ['governor.position', 'governor.word', 'governor.nkjp.tag',
              'governor.pos', 'governor.ms', 'conjunction.word',
              'conjunction.nkjp.tag', 'conjunction.pos', 'conjunction.ms',
              sentence["coordination"]["coordination_text_parts"][0], '1.dep.label', '1.head.word', '1.head.nkjp.tag',
              '1.head.pos', '1.head.ms', '1.words', sentence["coordination"]["parts_tokens"][0], '1.chars',
              sentence["coordination"]["coordination_text_parts"][1], '2.dep.label', '2.head.word', '2.head.nkjp.tag',
              '2.head.pos', '2.head.ms', '2.words', sentence["coordination"]["parts_tokens"][0], '2.chars', "text",
              sentence["sent_id"], 'genre', 'converted.from.file'] 
      df.loc[len(df)] = list
      return df

# %%
done = create_rows_from_parser(info, df)

# %%
done

# %%
import pandas as pd
class CSVInfo:
    def __init__(self, template):
        self.template = template
        self.csv = pd.DataFrame(columns=template.columns)
    
    def add_info_row(self, info):
        self.csv.loc[len(self.csv)] = info

# %%
def create_csv_template(columns_info_path):
    template = pd.read_csv(columns_info_path)
    return template

# %%
template = create_csv_template("/home/adglo/nlp/csv/UD_Polish-LFG.csv")
info_csv = CSVInfo(template)

# %%
info_csv.csv
# Out:
# Empty DataFrame
# Columns: [governor.position, governor.word, governor.tag, governor.pos, governor.ms, conjunction.word, conjunction.tag, conjunction.pos, conjunction.ms, no.conjuncts, L.conjunct, L.dep.label, L.head.word, L.head.tag, L.head.pos, L.head.ms, L.words, L.tokens, L.syllables, L.chars, R.conjunct, R.dep.label, R.head.word, R.head.tag, R.head.pos, R.head.ms, R.words, R.tokens, R.syllables, R.chars, sentence, sent_id, genre, converted.from.file]
# Index: []
#
# [0 rows x 34 columns]

# %%
line = [" ", " ", " ",
                    " ", " ", ["and", "and"],
                    " ", " ", " ",
                    " ", " ", " ",
                    " ", " ", " ",
                    " ", " ", " ",
                    " ", " ", " ",
                    " ", " ", " ",
                    " ", " ", " ",
                    " ", " ", " ",
                    " ", " ", " ", 
                    " "
                    ]

# %%
info_csv.add_info_row(line)
len(info_csv.csv.columns)
# Out:
# 34

# %%
info_csv.csv
# Out:
#   governor.position governor.word governor.tag governor.pos governor.ms  \
# 0
#
#   conjunction.word conjunction.tag conjunction.pos conjunction.ms  \
# 0       [and, and]
#
#   no.conjuncts  ... R.head.pos R.head.ms R.words R.tokens R.syllables R.chars  \
# 0               ...
#
#   sentence sent_id genre converted.from.file
# 0
#
# [1 rows x 34 columns]

# %% [markdown]
# 271, 385, 418, 465, 532, 59
