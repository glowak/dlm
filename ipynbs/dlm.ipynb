# %% [markdown]
# ## Trankit overview.

# %% [markdown]
# <div id="div1"> <img src="trankit_model.png", width=700> </div>

# %% [markdown]
# > Trankit outperforms other toolkits over all remaining tasks (e.g., POS
# > and morphological tagging) in which the improvement boost is substantial and significant for sentence segmentation and dependency parsing. For
# > example, English enjoys a 7.22% improvement for
# > sentence segmentation, a 3.92% and 4.37% improvement for UAS and LAS in dependency parsing.
#
# *Trankit: A Light-Weight Transformer-based Toolkit for Multilingual Natural Language Processing*
# https://doi.org/10.48550/arXiv.2101.03289
#
# ---
#
# ![](perf.png)
# ![](perf2.png)

# %% [markdown]
# ---
#
# ## Initializing the English pipeline from trankit

# %%
from trankit import Pipeline

p = Pipeline(lang='english', gpu=False, cache_dir='./cache')
# Out:
# Loading pretrained XLM-Roberta, this may take a while...
# Loading tokenizer for english
# Loading tagger for english
# Loading lemmatizer for english
# Loading NER tagger for english
# ==================================================
# Active language: english
# ==================================================

# %% [markdown]
# **Notable performance problems (only with my hardware):**
# - slow parsing for large datasets using CPU,
# - insufficient memory while using GPU (my GPU has only 3GiB memory, and it's filled FAST).
#
# ![](perf3.png)

# %% [markdown]
# ---
#
# ### Example dependency parsing using simple sentences from the presentation (20230123) and some random ones generated with ChatGPT.

# %%
text = '''I invited John, Mary, and Tom.
I played for an hour in the most famous jazz club in the whole of USA.
I played in the most famous jazz club in the whole of USA for an hour.
I invited to the club absolutely everybody in my address book.
I invited absolutely everybody in my address book to the club.
I took a shower, brushed my teeth, and went to bed.
I love the smell of freshly brewed coffee in the morning.
I prefer reading books to watching TV shows or movies.
The Simpsons is a beloved animated sitcom that has been entertaining audiences.
The Simpsons is the longest-running American primetime TV series.
Springfield is home to memorable characters.
Marge Simpson is the loving and supportive wife of Homer.
'''


all = p.posdep(text)

# %% [markdown]
# ---
#
# Trankit, while parsing, creates a dictionary with all the sentences and relevant data.
#
# **Example of generated dictionary:**

# %%
all
# Out:
# {'text': 'I invited John, Mary, and Tom.\nI played for an hour in the most famous jazz club in the whole of USA.\nI played in the most famous jazz club in the whole of USA for an hour.\nI invited to the club absolutely everybody in my address book.\nI invited absolutely everybody in my address book to the club.\nI took a shower, brushed my teeth, and went to bed.\nI love the smell of freshly brewed coffee in the morning.\nI prefer reading books to watching TV shows or movies.\nThe Simpsons is a beloved animated sitcom that has been entertaining audiences.\nThe Simpsons is the longest-running American primetime TV series.\nSpringfield is home to memorable characters.\nMarge Simpson is the loving and supportive wife of Homer.\n',
#  'sentences': [{'id': 1,
#    'text': 'I invited John, Mary, and Tom.',
#    'tokens': [{'id': 1,
#      'text': 'I',
#      'upos': 'PRON',
#      'xpos': 'PRP',
#      'feats': 'Case=Nom|Number=Sing|Person=1|PronType=Prs',
#      'head': 2,
#      'deprel': 'nsubj',
#      'dspan': (0, 1),
#      'span': (0, 1)},
#     {'id': 2,
#      'text': 'invited',
#      'upos': 'VERB',
#      'xpos': 'VBD',
#      'feats': 'Mood=Ind|Tense=Past|VerbForm=Fin',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (2, 9),
#      'span': (2, 9)},
#     {'id': 3,
#      'text': 'John',
#      'upos': 'PROPN',
#      'xpos': 'NNP',
#      'feats': 'Number=Sing',
#      'head': 2,
#      'deprel': 'obj',
#      'dspan': (10, 14),
#      'span': (10, 14)},
#     {'id': 4,
#      'text': ',',
#      'upos': 'PUNCT',
#      'xpos': ',',
#      'head': 5,
#      'deprel': 'punct',
#      'dspan': (14, 15),
#      'span': (14, 15)},
#     {'id': 5,
#      'text': 'Mary',
#      'upos': 'PROPN',
#      'xpos': 'NNP',
#      'feats': 'Number=Sing',
#      'head': 3,
#      'deprel': 'conj',
#      'dspan': (16, 20),
#      'span': (16, 20)},
#     {'id': 6,
#      'text': ',',
#      'upos': 'PUNCT',
#      'xpos': ',',
#      'head': 8,
#      'deprel': 'punct',
#      'dspan': (20, 21),
#      'span': (20, 21)},
#     {'id': 7,
#      'text': 'and',
#      'upos': 'CCONJ',
#      'xpos': 'CC',
#      'head': 8,
#      'deprel': 'cc',
#      'dspan': (22, 25),
#      'span': (22, 25)},
#     {'id': 8,
#      'text': 'Tom',
#      'upos': 'PROPN',
#      'xpos': 'NNP',
#      'feats': 'Number=Sing',
#      'head': 3,
#      'deprel': 'conj',
#      'dspan': (26, 29),
#      'span': (26, 29)},
#     {'id': 9,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 2,
#      'deprel': 'punct',
#      'dspan': (29, 30),
#      'span': (29, 30)}],
#    'dspan': (0, 30)},
#   {'id': 2,
#    'text': 'I played for an hour in the most famous jazz club in the whole of USA.',
#    'tokens': [{'id': 1,
#      'text': 'I',
#      'upos': 'PRON',
#      'xpos': 'PRP',
#      'feats': 'Case=Nom|Number=Sing|Person=1|PronType=Prs',
#      'head': 2,
#      'deprel': 'nsubj',
#      'dspan': (31, 32),
#      'span': (0, 1)},
#     {'id': 2,
#      'text': 'played',
#      'upos': 'VERB',
#      'xpos': 'VBD',
#      'feats': 'Mood=Ind|Tense=Past|VerbForm=Fin',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (33, 39),
#      'span': (2, 8)},
#     {'id': 3,
#      'text': 'for',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 5,
#      'deprel': 'case',
#      'dspan': (40, 43),
#      'span': (9, 12)},
#     {'id': 4,
#      'text': 'an',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Ind|PronType=Art',
#      'head': 5,
#      'deprel': 'det',
#      'dspan': (44, 46),
#      'span': (13, 15)},
#     {'id': 5,
#      'text': 'hour',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 2,
#      'deprel': 'obl',
#      'dspan': (47, 51),
#      'span': (16, 20)},
#     {'id': 6,
#      'text': 'in',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 11,
#      'deprel': 'case',
#      'dspan': (52, 54),
#      'span': (21, 23)},
#     {'id': 7,
#      'text': 'the',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 11,
#      'deprel': 'det',
#      'dspan': (55, 58),
#      'span': (24, 27)},
#     {'id': 8,
#      'text': 'most',
#      'upos': 'ADV',
#      'xpos': 'RBS',
#      'head': 9,
#      'deprel': 'advmod',
#      'dspan': (59, 63),
#      'span': (28, 32)},
#     {'id': 9,
#      'text': 'famous',
#      'upos': 'ADJ',
#      'xpos': 'JJ',
#      'feats': 'Degree=Pos',
#      'head': 11,
#      'deprel': 'amod',
#      'dspan': (64, 70),
#      'span': (33, 39)},
#     {'id': 10,
#      'text': 'jazz',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 11,
#      'deprel': 'compound',
#      'dspan': (71, 75),
#      'span': (40, 44)},
#     {'id': 11,
#      'text': 'club',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 2,
#      'deprel': 'obl',
#      'dspan': (76, 80),
#      'span': (45, 49)},
#     {'id': 12,
#      'text': 'in',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 14,
#      'deprel': 'case',
#      'dspan': (81, 83),
#      'span': (50, 52)},
#     {'id': 13,
#      'text': 'the',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 14,
#      'deprel': 'det',
#      'dspan': (84, 87),
#      'span': (53, 56)},
#     {'id': 14,
#      'text': 'whole',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 11,
#      'deprel': 'nmod',
#      'dspan': (88, 93),
#      'span': (57, 62)},
#     {'id': 15,
#      'text': 'of',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 16,
#      'deprel': 'case',
#      'dspan': (94, 96),
#      'span': (63, 65)},
#     {'id': 16,
#      'text': 'USA',
#      'upos': 'PROPN',
#      'xpos': 'NNP',
#      'feats': 'Number=Sing',
#      'head': 14,
#      'deprel': 'nmod',
#      'dspan': (97, 100),
#      'span': (66, 69)},
#     {'id': 17,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 2,
#      'deprel': 'punct',
#      'dspan': (100, 101),
#      'span': (69, 70)}],
#    'dspan': (31, 101)},
#   {'id': 3,
#    'text': 'I played in the most famous jazz club in the whole of USA for an hour.',
#    'tokens': [{'id': 1,
#      'text': 'I',
#      'upos': 'PRON',
#      'xpos': 'PRP',
#      'feats': 'Case=Nom|Number=Sing|Person=1|PronType=Prs',
#      'head': 2,
#      'deprel': 'nsubj',
#      'dspan': (102, 103),
#      'span': (0, 1)},
#     {'id': 2,
#      'text': 'played',
#      'upos': 'VERB',
#      'xpos': 'VBD',
#      'feats': 'Mood=Ind|Tense=Past|VerbForm=Fin',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (104, 110),
#      'span': (2, 8)},
#     {'id': 3,
#      'text': 'in',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 8,
#      'deprel': 'case',
#      'dspan': (111, 113),
#      'span': (9, 11)},
#     {'id': 4,
#      'text': 'the',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 8,
#      'deprel': 'det',
#      'dspan': (114, 117),
#      'span': (12, 15)},
#     {'id': 5,
#      'text': 'most',
#      'upos': 'ADV',
#      'xpos': 'RBS',
#      'head': 6,
#      'deprel': 'advmod',
#      'dspan': (118, 122),
#      'span': (16, 20)},
#     {'id': 6,
#      'text': 'famous',
#      'upos': 'ADJ',
#      'xpos': 'JJ',
#      'feats': 'Degree=Pos',
#      'head': 8,
#      'deprel': 'amod',
#      'dspan': (123, 129),
#      'span': (21, 27)},
#     {'id': 7,
#      'text': 'jazz',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 8,
#      'deprel': 'compound',
#      'dspan': (130, 134),
#      'span': (28, 32)},
#     {'id': 8,
#      'text': 'club',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 2,
#      'deprel': 'obl',
#      'dspan': (135, 139),
#      'span': (33, 37)},
#     {'id': 9,
#      'text': 'in',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 11,
#      'deprel': 'case',
#      'dspan': (140, 142),
#      'span': (38, 40)},
#     {'id': 10,
#      'text': 'the',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 11,
#      'deprel': 'det',
#      'dspan': (143, 146),
#      'span': (41, 44)},
#     {'id': 11,
#      'text': 'whole',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 8,
#      'deprel': 'nmod',
#      'dspan': (147, 152),
#      'span': (45, 50)},
#     {'id': 12,
#      'text': 'of',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 13,
#      'deprel': 'case',
#      'dspan': (153, 155),
#      'span': (51, 53)},
#     {'id': 13,
#      'text': 'USA',
#      'upos': 'PROPN',
#      'xpos': 'NNP',
#      'feats': 'Number=Sing',
#      'head': 11,
#      'deprel': 'nmod',
#      'dspan': (156, 159),
#      'span': (54, 57)},
#     {'id': 14,
#      'text': 'for',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 16,
#      'deprel': 'case',
#      'dspan': (160, 163),
#      'span': (58, 61)},
#     {'id': 15,
#      'text': 'an',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Ind|PronType=Art',
#      'head': 16,
#      'deprel': 'det',
#      'dspan': (164, 166),
#      'span': (62, 64)},
#     {'id': 16,
#      'text': 'hour',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 2,
#      'deprel': 'obl',
#      'dspan': (167, 171),
#      'span': (65, 69)},
#     {'id': 17,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 2,
#      'deprel': 'punct',
#      'dspan': (171, 172),
#      'span': (69, 70)}],
#    'dspan': (102, 172)},
#   {'id': 4,
#    'text': 'I invited to the club absolutely everybody in my address book.',
#    'tokens': [{'id': 1,
#      'text': 'I',
#      'upos': 'PRON',
#      'xpos': 'PRP',
#      'feats': 'Case=Nom|Number=Sing|Person=1|PronType=Prs',
#      'head': 2,
#      'deprel': 'nsubj',
#      'dspan': (173, 174),
#      'span': (0, 1)},
#     {'id': 2,
#      'text': 'invited',
#      'upos': 'VERB',
#      'xpos': 'VBD',
#      'feats': 'Mood=Ind|Tense=Past|VerbForm=Fin',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (175, 182),
#      'span': (2, 9)},
#     {'id': 3,
#      'text': 'to',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 5,
#      'deprel': 'case',
#      'dspan': (183, 185),
#      'span': (10, 12)},
#     {'id': 4,
#      'text': 'the',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 5,
#      'deprel': 'det',
#      'dspan': (186, 189),
#      'span': (13, 16)},
#     {'id': 5,
#      'text': 'club',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 2,
#      'deprel': 'obl',
#      'dspan': (190, 194),
#      'span': (17, 21)},
#     {'id': 6,
#      'text': 'absolutely',
#      'upos': 'ADV',
#      'xpos': 'RB',
#      'head': 7,
#      'deprel': 'advmod',
#      'dspan': (195, 205),
#      'span': (22, 32)},
#     {'id': 7,
#      'text': 'everybody',
#      'upos': 'PRON',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 2,
#      'deprel': 'obj',
#      'dspan': (206, 215),
#      'span': (33, 42)},
#     {'id': 8,
#      'text': 'in',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 11,
#      'deprel': 'case',
#      'dspan': (216, 218),
#      'span': (43, 45)},
#     {'id': 9,
#      'text': 'my',
#      'upos': 'PRON',
#      'xpos': 'PRP$',
#      'feats': 'Number=Sing|Person=1|Poss=Yes|PronType=Prs',
#      'head': 11,
#      'deprel': 'nmod:poss',
#      'dspan': (219, 221),
#      'span': (46, 48)},
#     {'id': 10,
#      'text': 'address',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 11,
#      'deprel': 'compound',
#      'dspan': (222, 229),
#      'span': (49, 56)},
#     {'id': 11,
#      'text': 'book',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 7,
#      'deprel': 'nmod',
#      'dspan': (230, 234),
#      'span': (57, 61)},
#     {'id': 12,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 2,
#      'deprel': 'punct',
#      'dspan': (234, 235),
#      'span': (61, 62)}],
#    'dspan': (173, 235)},
#   {'id': 5,
#    'text': 'I invited absolutely everybody in my address book to the club.',
#    'tokens': [{'id': 1,
#      'text': 'I',
#      'upos': 'PRON',
#      'xpos': 'PRP',
#      'feats': 'Case=Nom|Number=Sing|Person=1|PronType=Prs',
#      'head': 2,
#      'deprel': 'nsubj',
#      'dspan': (236, 237),
#      'span': (0, 1)},
#     {'id': 2,
#      'text': 'invited',
#      'upos': 'VERB',
#      'xpos': 'VBD',
#      'feats': 'Mood=Ind|Tense=Past|VerbForm=Fin',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (238, 245),
#      'span': (2, 9)},
#     {'id': 3,
#      'text': 'absolutely',
#      'upos': 'ADV',
#      'xpos': 'RB',
#      'head': 4,
#      'deprel': 'advmod',
#      'dspan': (246, 256),
#      'span': (10, 20)},
#     {'id': 4,
#      'text': 'everybody',
#      'upos': 'PRON',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 2,
#      'deprel': 'obj',
#      'dspan': (257, 266),
#      'span': (21, 30)},
#     {'id': 5,
#      'text': 'in',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 8,
#      'deprel': 'case',
#      'dspan': (267, 269),
#      'span': (31, 33)},
#     {'id': 6,
#      'text': 'my',
#      'upos': 'PRON',
#      'xpos': 'PRP$',
#      'feats': 'Number=Sing|Person=1|Poss=Yes|PronType=Prs',
#      'head': 8,
#      'deprel': 'nmod:poss',
#      'dspan': (270, 272),
#      'span': (34, 36)},
#     {'id': 7,
#      'text': 'address',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 8,
#      'deprel': 'compound',
#      'dspan': (273, 280),
#      'span': (37, 44)},
#     {'id': 8,
#      'text': 'book',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 4,
#      'deprel': 'nmod',
#      'dspan': (281, 285),
#      'span': (45, 49)},
#     {'id': 9,
#      'text': 'to',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 11,
#      'deprel': 'case',
#      'dspan': (286, 288),
#      'span': (50, 52)},
#     {'id': 10,
#      'text': 'the',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 11,
#      'deprel': 'det',
#      'dspan': (289, 292),
#      'span': (53, 56)},
#     {'id': 11,
#      'text': 'club',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 2,
#      'deprel': 'obl',
#      'dspan': (293, 297),
#      'span': (57, 61)},
#     {'id': 12,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 2,
#      'deprel': 'punct',
#      'dspan': (297, 298),
#      'span': (61, 62)}],
#    'dspan': (236, 298)},
#   {'id': 6,
#    'text': 'I took a shower, brushed my teeth, and went to bed.',
#    'tokens': [{'id': 1,
#      'text': 'I',
#      'upos': 'PRON',
#      'xpos': 'PRP',
#      'feats': 'Case=Nom|Number=Sing|Person=1|PronType=Prs',
#      'head': 2,
#      'deprel': 'nsubj',
#      'dspan': (299, 300),
#      'span': (0, 1)},
#     {'id': 2,
#      'text': 'took',
#      'upos': 'VERB',
#      'xpos': 'VBD',
#      'feats': 'Mood=Ind|Tense=Past|VerbForm=Fin',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (301, 305),
#      'span': (2, 6)},
#     {'id': 3,
#      'text': 'a',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Ind|PronType=Art',
#      'head': 4,
#      'deprel': 'det',
#      'dspan': (306, 307),
#      'span': (7, 8)},
#     {'id': 4,
#      'text': 'shower',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 2,
#      'deprel': 'obj',
#      'dspan': (308, 314),
#      'span': (9, 15)},
#     {'id': 5,
#      'text': ',',
#      'upos': 'PUNCT',
#      'xpos': ',',
#      'head': 6,
#      'deprel': 'punct',
#      'dspan': (314, 315),
#      'span': (15, 16)},
#     {'id': 6,
#      'text': 'brushed',
#      'upos': 'VERB',
#      'xpos': 'VBD',
#      'feats': 'Mood=Ind|Tense=Past|VerbForm=Fin',
#      'head': 2,
#      'deprel': 'conj',
#      'dspan': (316, 323),
#      'span': (17, 24)},
#     {'id': 7,
#      'text': 'my',
#      'upos': 'PRON',
#      'xpos': 'PRP$',
#      'feats': 'Number=Sing|Person=1|Poss=Yes|PronType=Prs',
#      'head': 8,
#      'deprel': 'nmod:poss',
#      'dspan': (324, 326),
#      'span': (25, 27)},
#     {'id': 8,
#      'text': 'teeth',
#      'upos': 'NOUN',
#      'xpos': 'NNS',
#      'feats': 'Number=Plur',
#      'head': 6,
#      'deprel': 'obj',
#      'dspan': (327, 332),
#      'span': (28, 33)},
#     {'id': 9,
#      'text': ',',
#      'upos': 'PUNCT',
#      'xpos': ',',
#      'head': 11,
#      'deprel': 'punct',
#      'dspan': (332, 333),
#      'span': (33, 34)},
#     {'id': 10,
#      'text': 'and',
#      'upos': 'CCONJ',
#      'xpos': 'CC',
#      'head': 11,
#      'deprel': 'cc',
#      'dspan': (334, 337),
#      'span': (35, 38)},
#     {'id': 11,
#      'text': 'went',
#      'upos': 'VERB',
#      'xpos': 'VBD',
#      'feats': 'Mood=Ind|Tense=Past|VerbForm=Fin',
#      'head': 2,
#      'deprel': 'conj',
#      'dspan': (338, 342),
#      'span': (39, 43)},
#     {'id': 12,
#      'text': 'to',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 13,
#      'deprel': 'case',
#      'dspan': (343, 345),
#      'span': (44, 46)},
#     {'id': 13,
#      'text': 'bed',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 11,
#      'deprel': 'obl',
#      'dspan': (346, 349),
#      'span': (47, 50)},
#     {'id': 14,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 2,
#      'deprel': 'punct',
#      'dspan': (349, 350),
#      'span': (50, 51)}],
#    'dspan': (299, 350)},
#   {'id': 7,
#    'text': 'I love the smell of freshly brewed coffee in the morning.',
#    'tokens': [{'id': 1,
#      'text': 'I',
#      'upos': 'PRON',
#      'xpos': 'PRP',
#      'feats': 'Case=Nom|Number=Sing|Person=1|PronType=Prs',
#      'head': 2,
#      'deprel': 'nsubj',
#      'dspan': (351, 352),
#      'span': (0, 1)},
#     {'id': 2,
#      'text': 'love',
#      'upos': 'VERB',
#      'xpos': 'VBP',
#      'feats': 'Mood=Ind|Tense=Pres|VerbForm=Fin',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (353, 357),
#      'span': (2, 6)},
#     {'id': 3,
#      'text': 'the',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 4,
#      'deprel': 'det',
#      'dspan': (358, 361),
#      'span': (7, 10)},
#     {'id': 4,
#      'text': 'smell',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 2,
#      'deprel': 'obj',
#      'dspan': (362, 367),
#      'span': (11, 16)},
#     {'id': 5,
#      'text': 'of',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 8,
#      'deprel': 'case',
#      'dspan': (368, 370),
#      'span': (17, 19)},
#     {'id': 6,
#      'text': 'freshly',
#      'upos': 'ADV',
#      'xpos': 'RB',
#      'head': 7,
#      'deprel': 'advmod',
#      'dspan': (371, 378),
#      'span': (20, 27)},
#     {'id': 7,
#      'text': 'brewed',
#      'upos': 'VERB',
#      'xpos': 'VBN',
#      'feats': 'Tense=Past|VerbForm=Part',
#      'head': 8,
#      'deprel': 'amod',
#      'dspan': (379, 385),
#      'span': (28, 34)},
#     {'id': 8,
#      'text': 'coffee',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 4,
#      'deprel': 'nmod',
#      'dspan': (386, 392),
#      'span': (35, 41)},
#     {'id': 9,
#      'text': 'in',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 11,
#      'deprel': 'case',
#      'dspan': (393, 395),
#      'span': (42, 44)},
#     {'id': 10,
#      'text': 'the',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 11,
#      'deprel': 'det',
#      'dspan': (396, 399),
#      'span': (45, 48)},
#     {'id': 11,
#      'text': 'morning',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 4,
#      'deprel': 'nmod',
#      'dspan': (400, 407),
#      'span': (49, 56)},
#     {'id': 12,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 2,
#      'deprel': 'punct',
#      'dspan': (407, 408),
#      'span': (56, 57)}],
#    'dspan': (351, 408)},
#   {'id': 8,
#    'text': 'I prefer reading books to watching TV shows or movies.',
#    'tokens': [{'id': 1,
#      'text': 'I',
#      'upos': 'PRON',
#      'xpos': 'PRP',
#      'feats': 'Case=Nom|Number=Sing|Person=1|PronType=Prs',
#      'head': 2,
#      'deprel': 'nsubj',
#      'dspan': (409, 410),
#      'span': (0, 1)},
#     {'id': 2,
#      'text': 'prefer',
#      'upos': 'VERB',
#      'xpos': 'VBP',
#      'feats': 'Mood=Ind|Tense=Pres|VerbForm=Fin',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (411, 417),
#      'span': (2, 8)},
#     {'id': 3,
#      'text': 'reading',
#      'upos': 'VERB',
#      'xpos': 'VBG',
#      'feats': 'VerbForm=Ger',
#      'head': 2,
#      'deprel': 'xcomp',
#      'dspan': (418, 425),
#      'span': (9, 16)},
#     {'id': 4,
#      'text': 'books',
#      'upos': 'NOUN',
#      'xpos': 'NNS',
#      'feats': 'Number=Plur',
#      'head': 3,
#      'deprel': 'obj',
#      'dspan': (426, 431),
#      'span': (17, 22)},
#     {'id': 5,
#      'text': 'to',
#      'upos': 'SCONJ',
#      'xpos': 'IN',
#      'head': 6,
#      'deprel': 'mark',
#      'dspan': (432, 434),
#      'span': (23, 25)},
#     {'id': 6,
#      'text': 'watching',
#      'upos': 'VERB',
#      'xpos': 'VBG',
#      'feats': 'VerbForm=Ger',
#      'head': 2,
#      'deprel': 'advcl',
#      'dspan': (435, 443),
#      'span': (26, 34)},
#     {'id': 7,
#      'text': 'TV',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 8,
#      'deprel': 'compound',
#      'dspan': (444, 446),
#      'span': (35, 37)},
#     {'id': 8,
#      'text': 'shows',
#      'upos': 'NOUN',
#      'xpos': 'NNS',
#      'feats': 'Number=Plur',
#      'head': 6,
#      'deprel': 'obj',
#      'dspan': (447, 452),
#      'span': (38, 43)},
#     {'id': 9,
#      'text': 'or',
#      'upos': 'CCONJ',
#      'xpos': 'CC',
#      'head': 10,
#      'deprel': 'cc',
#      'dspan': (453, 455),
#      'span': (44, 46)},
#     {'id': 10,
#      'text': 'movies',
#      'upos': 'NOUN',
#      'xpos': 'NNS',
#      'feats': 'Number=Plur',
#      'head': 8,
#      'deprel': 'conj',
#      'dspan': (456, 462),
#      'span': (47, 53)},
#     {'id': 11,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 2,
#      'deprel': 'punct',
#      'dspan': (462, 463),
#      'span': (53, 54)}],
#    'dspan': (409, 463)},
#   {'id': 9,
#    'text': 'The Simpsons is a beloved animated sitcom that has been entertaining audiences.',
#    'tokens': [{'id': 1,
#      'text': 'The',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 2,
#      'deprel': 'det',
#      'dspan': (464, 467),
#      'span': (0, 3)},
#     {'id': 2,
#      'text': 'Simpsons',
#      'upos': 'PROPN',
#      'xpos': 'NNPS',
#      'feats': 'Number=Plur',
#      'head': 7,
#      'deprel': 'nsubj',
#      'dspan': (468, 476),
#      'span': (4, 12)},
#     {'id': 3,
#      'text': 'is',
#      'upos': 'AUX',
#      'xpos': 'VBZ',
#      'feats': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#      'head': 7,
#      'deprel': 'cop',
#      'dspan': (477, 479),
#      'span': (13, 15)},
#     {'id': 4,
#      'text': 'a',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Ind|PronType=Art',
#      'head': 7,
#      'deprel': 'det',
#      'dspan': (480, 481),
#      'span': (16, 17)},
#     {'id': 5,
#      'text': 'beloved',
#      'upos': 'ADJ',
#      'xpos': 'JJ',
#      'feats': 'Degree=Pos',
#      'head': 7,
#      'deprel': 'amod',
#      'dspan': (482, 489),
#      'span': (18, 25)},
#     {'id': 6,
#      'text': 'animated',
#      'upos': 'ADJ',
#      'xpos': 'JJ',
#      'feats': 'Degree=Pos',
#      'head': 7,
#      'deprel': 'amod',
#      'dspan': (490, 498),
#      'span': (26, 34)},
#     {'id': 7,
#      'text': 'sitcom',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (499, 505),
#      'span': (35, 41)},
#     {'id': 8,
#      'text': 'that',
#      'upos': 'PRON',
#      'xpos': 'WDT',
#      'feats': 'PronType=Rel',
#      'head': 11,
#      'deprel': 'nsubj',
#      'dspan': (506, 510),
#      'span': (42, 46)},
#     {'id': 9,
#      'text': 'has',
#      'upos': 'AUX',
#      'xpos': 'VBZ',
#      'feats': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#      'head': 11,
#      'deprel': 'aux',
#      'dspan': (511, 514),
#      'span': (47, 50)},
#     {'id': 10,
#      'text': 'been',
#      'upos': 'AUX',
#      'xpos': 'VBN',
#      'feats': 'Tense=Past|VerbForm=Part',
#      'head': 11,
#      'deprel': 'aux',
#      'dspan': (515, 519),
#      'span': (51, 55)},
#     {'id': 11,
#      'text': 'entertaining',
#      'upos': 'VERB',
#      'xpos': 'VBG',
#      'feats': 'Tense=Pres|VerbForm=Part',
#      'head': 7,
#      'deprel': 'acl:relcl',
#      'dspan': (520, 532),
#      'span': (56, 68)},
#     {'id': 12,
#      'text': 'audiences',
#      'upos': 'NOUN',
#      'xpos': 'NNS',
#      'feats': 'Number=Plur',
#      'head': 11,
#      'deprel': 'obj',
#      'dspan': (533, 542),
#      'span': (69, 78)},
#     {'id': 13,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 7,
#      'deprel': 'punct',
#      'dspan': (542, 543),
#      'span': (78, 79)}],
#    'dspan': (464, 543)},
#   {'id': 10,
#    'text': 'The Simpsons is the longest-running American primetime TV series.',
#    'tokens': [{'id': 1,
#      'text': 'The',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 2,
#      'deprel': 'det',
#      'dspan': (544, 547),
#      'span': (0, 3)},
#     {'id': 2,
#      'text': 'Simpsons',
#      'upos': 'PROPN',
#      'xpos': 'NNPS',
#      'feats': 'Number=Plur',
#      'head': 11,
#      'deprel': 'nsubj',
#      'dspan': (548, 556),
#      'span': (4, 12)},
#     {'id': 3,
#      'text': 'is',
#      'upos': 'AUX',
#      'xpos': 'VBZ',
#      'feats': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#      'head': 11,
#      'deprel': 'cop',
#      'dspan': (557, 559),
#      'span': (13, 15)},
#     {'id': 4,
#      'text': 'the',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 11,
#      'deprel': 'det',
#      'dspan': (560, 563),
#      'span': (16, 19)},
#     {'id': 5,
#      'text': 'longest',
#      'upos': 'ADV',
#      'xpos': 'RBS',
#      'feats': 'Degree=Sup',
#      'head': 7,
#      'deprel': 'advmod',
#      'dspan': (564, 571),
#      'span': (20, 27)},
#     {'id': 6,
#      'text': '-',
#      'upos': 'PUNCT',
#      'xpos': 'HYPH',
#      'head': 7,
#      'deprel': 'punct',
#      'dspan': (571, 572),
#      'span': (27, 28)},
#     {'id': 7,
#      'text': 'running',
#      'upos': 'VERB',
#      'xpos': 'VBG',
#      'feats': 'VerbForm=Ger',
#      'head': 11,
#      'deprel': 'amod',
#      'dspan': (572, 579),
#      'span': (28, 35)},
#     {'id': 8,
#      'text': 'American',
#      'upos': 'ADJ',
#      'xpos': 'JJ',
#      'feats': 'Degree=Pos',
#      'head': 11,
#      'deprel': 'amod',
#      'dspan': (580, 588),
#      'span': (36, 44)},
#     {'id': 9,
#      'text': 'primetime',
#      'upos': 'ADJ',
#      'xpos': 'JJ',
#      'feats': 'Degree=Pos',
#      'head': 11,
#      'deprel': 'amod',
#      'dspan': (589, 598),
#      'span': (45, 54)},
#     {'id': 10,
#      'text': 'TV',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 11,
#      'deprel': 'compound',
#      'dspan': (599, 601),
#      'span': (55, 57)},
#     {'id': 11,
#      'text': 'series',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (602, 608),
#      'span': (58, 64)},
#     {'id': 12,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 11,
#      'deprel': 'punct',
#      'dspan': (608, 609),
#      'span': (64, 65)}],
#    'dspan': (544, 609)},
#   {'id': 11,
#    'text': 'Springfield is home to memorable characters.',
#    'tokens': [{'id': 1,
#      'text': 'Springfield',
#      'upos': 'PROPN',
#      'xpos': 'NNP',
#      'feats': 'Number=Sing',
#      'head': 3,
#      'deprel': 'nsubj',
#      'dspan': (610, 621),
#      'span': (0, 11)},
#     {'id': 2,
#      'text': 'is',
#      'upos': 'AUX',
#      'xpos': 'VBZ',
#      'feats': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#      'head': 3,
#      'deprel': 'cop',
#      'dspan': (622, 624),
#      'span': (12, 14)},
#     {'id': 3,
#      'text': 'home',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (625, 629),
#      'span': (15, 19)},
#     {'id': 4,
#      'text': 'to',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 6,
#      'deprel': 'case',
#      'dspan': (630, 632),
#      'span': (20, 22)},
#     {'id': 5,
#      'text': 'memorable',
#      'upos': 'ADJ',
#      'xpos': 'JJ',
#      'feats': 'Degree=Pos',
#      'head': 6,
#      'deprel': 'amod',
#      'dspan': (633, 642),
#      'span': (23, 32)},
#     {'id': 6,
#      'text': 'characters',
#      'upos': 'NOUN',
#      'xpos': 'NNS',
#      'feats': 'Number=Plur',
#      'head': 3,
#      'deprel': 'nmod',
#      'dspan': (643, 653),
#      'span': (33, 43)},
#     {'id': 7,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 3,
#      'deprel': 'punct',
#      'dspan': (653, 654),
#      'span': (43, 44)}],
#    'dspan': (610, 654)},
#   {'id': 12,
#    'text': 'Marge Simpson is the loving and supportive wife of Homer.',
#    'tokens': [{'id': 1,
#      'text': 'Marge',
#      'upos': 'PROPN',
#      'xpos': 'NNP',
#      'feats': 'Number=Sing',
#      'head': 8,
#      'deprel': 'nsubj',
#      'dspan': (655, 660),
#      'span': (0, 5)},
#     {'id': 2,
#      'text': 'Simpson',
#      'upos': 'PROPN',
#      'xpos': 'NNP',
#      'feats': 'Number=Sing',
#      'head': 1,
#      'deprel': 'flat',
#      'dspan': (661, 668),
#      'span': (6, 13)},
#     {'id': 3,
#      'text': 'is',
#      'upos': 'AUX',
#      'xpos': 'VBZ',
#      'feats': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#      'head': 8,
#      'deprel': 'cop',
#      'dspan': (669, 671),
#      'span': (14, 16)},
#     {'id': 4,
#      'text': 'the',
#      'upos': 'DET',
#      'xpos': 'DT',
#      'feats': 'Definite=Def|PronType=Art',
#      'head': 8,
#      'deprel': 'det',
#      'dspan': (672, 675),
#      'span': (17, 20)},
#     {'id': 5,
#      'text': 'loving',
#      'upos': 'ADJ',
#      'xpos': 'JJ',
#      'feats': 'Degree=Pos',
#      'head': 8,
#      'deprel': 'amod',
#      'dspan': (676, 682),
#      'span': (21, 27)},
#     {'id': 6,
#      'text': 'and',
#      'upos': 'CCONJ',
#      'xpos': 'CC',
#      'head': 7,
#      'deprel': 'cc',
#      'dspan': (683, 686),
#      'span': (28, 31)},
#     {'id': 7,
#      'text': 'supportive',
#      'upos': 'ADJ',
#      'xpos': 'JJ',
#      'feats': 'Degree=Pos',
#      'head': 5,
#      'deprel': 'conj',
#      'dspan': (687, 697),
#      'span': (32, 42)},
#     {'id': 8,
#      'text': 'wife',
#      'upos': 'NOUN',
#      'xpos': 'NN',
#      'feats': 'Number=Sing',
#      'head': 0,
#      'deprel': 'root',
#      'dspan': (698, 702),
#      'span': (43, 47)},
#     {'id': 9,
#      'text': 'of',
#      'upos': 'ADP',
#      'xpos': 'IN',
#      'head': 10,
#      'deprel': 'case',
#      'dspan': (703, 705),
#      'span': (48, 50)},
#     {'id': 10,
#      'text': 'Homer',
#      'upos': 'PROPN',
#      'xpos': 'NNP',
#      'feats': 'Number=Sing',
#      'head': 8,
#      'deprel': 'nmod',
#      'dspan': (706, 711),
#      'span': (51, 56)},
#     {'id': 11,
#      'text': '.',
#      'upos': 'PUNCT',
#      'xpos': '.',
#      'head': 8,
#      'deprel': 'punct',
#      'dspan': (711, 712),
#      'span': (56, 57)}],
#    'dspan': (655, 712)}],
#  'lang': 'english'}

# %% [markdown]
# **Note that this output** doesn't have the information about dependency length (but can be extracted).

# %% [markdown]
# **Auxiliary functions for generating:**
# (a) dictionary with relevant data for generating a $LaTeX$ file with dependency trees,
# (b) adding other useful information, such as placement of the governor.

# %%
def parse_sentence(dep_parsed):
    dict = {'parsed_latex': []}
    parsed = ""
    deps = []
    for i in range(len(dep_parsed["sentences"])):
        for j in range(len(dep_parsed["sentences"][i]["tokens"])):
            if(dep_parsed["sentences"][i]["tokens"][j]["text"] in ("$", "%", "&")):
                rooted = "\\" + dep_parsed["sentences"][i]["tokens"][j]["text"] + " \&"
            else:
                rooted = dep_parsed["sentences"][i]["tokens"][j]["text"] + " \&"
            parsed += rooted
            deps.append((dep_parsed["sentences"][i]["tokens"][j]["head"], dep_parsed["sentences"][i]["tokens"][j]["id"], dep_parsed["sentences"][i]["tokens"][j]["deprel"]))

        parsed += " \\\\"
        dict["parsed_latex"].append({'id': i+1, 'sentence': parsed, 'dependencies': deps})
        parsed = ""
        deps = [] 

    return dict

def extract_info(dep_parsed):
    direction = {"left": [], "right": []}
    for i in range(len(dep_parsed["parsed_latex"])):
        depends = dep_parsed["parsed_latex"][i]["dependencies"]
        for deps in depends:
            dependency_length_words = abs(deps[0] - deps[1])
            if(deps[1] > deps[0] and deps[2] != "PUNCT"):
                direction["left"].append(dependency_length_words)
            elif(deps[1] < deps[0] and deps[2] != "PUNCT"):
                direction["right"].append(dependency_length_words)
    return direction

# %% [markdown]
# **Function generating the $LaTeX$ file with dependency trees.**

# %%
def generate_latex(template, id, dep_parsed):
    filename = f'dependency_{id}.tex'
    latex_dependency_begin = '''\\hspace*{-4cm}
    \\begin{dependency}[theme = simple]\n'''

    latex_dependency_end = "\\end{dependency}\n"
    latex_sentence_begin = "\\begin{deptext}[column sep = 0.5em]\n"
    latex_sentence_end = "\\end{deptext}\n"
    code = ""

    for i in range(len(dep_parsed["parsed_latex"])):
        depends = dep_parsed["parsed_latex"][i]["dependencies"]
        edges = ""
        if(len(depends) < 18): # print only these sentences, that have less than 18 branches
            for deps in depends:
                #dependency_length_words = abs(deps[0] - deps[1])
                label = deps[2]
                if(deps[0] == 0):
                    edges += (f"\deproot[edge unit distance=4ex, edge style=dotted]{ {deps[1]} }{{}}\n")
                elif(deps[2] != "PUNCT"):
                    # labels: distance in words
                    # edges += (f"\depedge{ {deps[0]} }{ {deps[1]} }{ {abs(deps[0] - deps[1])} }\n")

                    # labels: upos
                    edges += (f"\depedge{ {deps[0]} }{ {deps[1]} }{ {label} }\n")
            code += latex_dependency_begin + latex_sentence_begin + dep_parsed["parsed_latex"][i]["sentence"] + "\n" + latex_sentence_end + edges +"\n" + latex_dependency_end + "\n"

    with open(filename, "w") as latex_file:
        latex = template.replace(r'\VAR{sentence}', code)
        latex_file.write(latex)


with open("template_dep.tex") as template_file:
    global latex_code
    latex_code = template_file.read()

# %% [markdown]
# **Parsing the example text and creating a $LaTeX$ file for insight.**

# %%
dep_parsed = parse_sentence(all)
dirs = extract_info(dep_parsed)
generate_latex(latex_code, "example", dep_parsed)

# %% [markdown]
# **Attempt at calculating basic statistics about the data.**

# %%
import statistics as st
print("Mean distance in words when governor on the left: " + str(round(st.mean(dirs["left"]), 2)) 
      + "\nMean distance in words when governor on the right: " + str(round(st.mean(dirs["right"]), 2)))

# %% [markdown]
# ---
#
# ## Using a short snippet of COCA for sample parsing.

# %% [markdown]
# https://www.corpusdata.org/formats.asp

# %%
import re
example_corpus = open("text_blog.txt", "r")
snippet = example_corpus.readlines()[1:5]
plain = ""
for sent in snippet:
    plain += sent

# Clean the data a bit
patterns = ["@........", "<h>.*?<p>", "<p>"]
result = plain
for pat in patterns:
    result = re.sub(pat, "", result)

print(result)
# Out:
#   Emerging from the fog , as it were . I always forget just how all-consuming the first throes of rehearsal for an opera can be . Especially if , as in this case , the lead role is not yet cast ( it 's a hellishly difficult sing , and the intended singer pulled out just before musical rehearsals began . He is a consummate professional , so he must have had very solid reasons , but that still leaves other colleagues ( luckily not me : the role I am covering is not so big ) a bit adrift in a piece which requires long dialogues with the lead ... Let 's just say that does n't lead to happy relaxation , on the whole .  And I also have to admit to having been nervous before the initial music call . I had n't sung for this music director before ; and no matter what anyone says , it FEELS like an audition when you sing for someone in a position of power for the first time . It would of course have helped to have had masses of   had a more voice-friendly opera to start with , but hey , beggars ca n't be choosers , and at least ( despite having missed my very first solo entrance due to still ... STILL ! ! ! ... having to mentally translate numbers from German to English , rats rats RATS ! ! ) we 've got that bit over with and from now on it 's simply business .  The interesting bit is just HOW exhausted one feels during this process . The brain seems to focus itself very narrowly , and everything which does n't directly concern the learning of this particular music is ignored . ( I remember coming across a colleague , who shall remain unnamed , stealing a roll of loo paper from the theatre , in the throes of rehearsals ; the ( understandable ) rationale was that there really had n't been enough time to hit the supermarket ... ) .  However I must admit that despite all the stress and uncertainty , I really do love these first few rehearsals . A question of how your role fits in   amusing - the court ladies get to sing some really rather beautiful chords before my character leaps in and spoils it all ! ) thing is rather marvellous .  I am an English opera singer trying occasionally to make sense of my life in Germany . Random influences from my past include : studying languages ( French and Russian ) at Cambridge ; drinking far too much vodka with Russians during said " study " ; nearly a year 's busking ; discovering my true voice later than most ; supporting the continuing discovery of my voice with various colourful
#   The holidays can be a difficult time for some people , but many organizations are collecting food to ease the pain for some , with a few upcoming events likely to be the focus of some local poster printing .  The 4th annual Basket of Miracles Thanksgiving food drive , sponsored by Miracles for Kids , will deliver food baskets to 100 needy families whose critically ill children are being treated at CHOC Children 's Hospital .  Volunteers are needed to help deliver the food baskets from 9:00 am -- 1:00 pm on Tuesday , November 20 . Monetary donations are always accepted .  Also next week , celebrity TyRon Jackson will host a free Thanksgiving dinner from 12:00 noon -- 5:00 pm on Thursday , November 22 in Peppertree Park , 230 W. First Street , Tustin . The free meal will include turkey and all the trimmings for those in need . There will also be guest speakers and live entertainment . For more information , visit TyRon 's Facebook or Twitter page .  Moving into December , the hospital 's Holiday Drive will be   of bread , meat , eggs , fruit , vegetables , dairy , toys , games , and books will be accepted . Volunteers are required to help assemble the baskets and gift bags . December 13 will be used to set up the event , assembly of the bags will take place over December 14 -- 15 , and delivery will commence on Monday , December 17 , with proceedings running from 9:00 am -- 2:00 pm on each day .  One-hundred and sixty Southern California families will be the recipients of the food and toys . To volunteer , or donate items
#   European researchers have published a study which analyses the health economics of increased dairy foods and related reduction in risk of osteoporotic fractures in the population aged over 50 .  The study was based on a new analytical model that links nutrition and fracture risk , and health economics . It was based on data from the Netherlands , France and Sweden , countries which have varying levels of dairy products intake in the population .  Study co-author Professor Ren Rizzoli , Professor of Medicine and Head of the Division of Bone Disease at the University Hospitals of Geneva , said , " Despite the fact that the effects of foods on health are recognized , there are no accepted and proven methodologies to assess the health-economic impacts of foods on the general population . Although this model may be further refined , it does provide a straightforward and easy-to-use method to assess the health-economic impact of food products on health , well-being and costs . " The publication ' Dairy foods and Osteoporosis : An example of Assessing the Health -- Economic Impact of Food Products ' has been published online in the scientific journal   different types of foods ( including in certain fish and greens ) , however around 60 to 70% of daily calcium intake in Western Countries is derived from dairy products . In addition to calcium , dairy products also provide a large variety of essential nutrients such as minerals , vitamins and proteins that , along with vitamin D , are also beneficial to bone health .  Low dietary intake of calcium has been associated with decreased bone density and increased risk of osteoporosis , a disease where bone becomes less dense and prone to fracture . Fractures are a costly public health burden , resulting in increased mortality , disability , pain and loss of health-related quality of life . In terms of health-economic burden , hip fractures in particular result in huge expenditures for hospitalization , rehabilitation , and long-term nursing care .  The researchers calculated the number of disability-adjusted life years ( DALYS ) lost due to hip fractures associated with low nutritional calcium intake and the number of hip fractures that could potentially be prevented each year with intake of additional dairy products .   fractures , followed by Sweden ( 455 ) and the Netherlands ( 132 ) . This represents a substantial health cost savings of approximately 129 million , 34 million and 6 million Euros in these countries , respectively .  " Our study likely underestimates the potential cost savings of increased dietary calcium in that it relies on existing figures for the senior population and does not take into account the long-term benefits to the younger generation , " said Rizzoli .  He added , " Adequate nutritional intake and regular exercise during childhood and adolescence , both necessary for the development of peak bone mass , may contribute to bone strength
#   The current business model for business books is broken , Osterwalder said . There are too many books and too few readers . Every year , another 11,000 new business books pile on top the 250,000-space of competing titles . The average book sells only 250 copies per year . Worse , book sales are declining : a 12% drop from 2007 to 2009 . If Osterwalder wanted to create a book on business models that people would love to buy , he would need to innovate the business model for business book production and sales .  From the start , Osterwalder asked people what they hated about current business books . People said existing books were too fat with turgid prose but at the same time too light on substance . Second , people found the books impractical because they lacked useful " Monday morning " actions items . Finally , the books were too text-heavy , missing the richer , reinforcing learning experience of a text-and-graphics combination .  To address these problems , Osterwalder envisioned something more like a coffee-table book akin to architecture books , being simultaneously informative and beautiful .  Osterwalder   to break the rules of traditional business books to publish his book . At the time , Osterwalder was an unknown author from Switzerland wanting to create a book with high production values , expensive color printing , and a very un-business-book approach . The only solution was self-publishing .  But , self-publishing would n't be easy because Osterwalder had neither the cash , book production resources ( editors , designers , etc. ) , marketing department , nor distribution assets of a publishing house .  To solve the problem , Osterwalder recruited peers to co-create the book . Ultimately , 470 people contributed to the book in a wide variety of ways . People joined Osterwalder for early access to the ideas , to be part of something bigger , and for the stimulating collaborative process of working on the topic . Not only did this community of contributors help make the book , but they were also its best sales force .  To raise money , Osterwalder offered advanced sales under a " pay me now to reserve a copy " philosophy . Demand for   the price from $24 to $36 to $54 to $81 . And , just before publication , he offered a last-minute premium deal : for $250 , the buyer would be listed in the book as a contributor who helped make it happen . For distribution , Osterwalder ultimately chose Fulfillment by Amazon .  The book quickly became a bestseller in business and in the top 100 of all books selling on Amazon . Osterwalder 's success in self-publishing attracted the attention of Wiley and other traditional publishers , who would never have taken a risk on Osterwalder 's book . " Once you 're successful , everyone wants in , " Osterwalder said . After tough negotiations , he signed with Wiley . To date , over 200,000 copies have sold and the book has been translated into 22 languages .  Thank you , Katherine ! I thought Alex 's story was so inspiring , and he 's continuing to innovate and create a whole community around business model design by making the tools available for free under a Creative Commons license . It 's a wonderful   : **40;4018;TOOLONG  I had not read this post yet and just got to do so today ( been heads down in execution for WBF . )  I was not able to attend BIF7 and even though I was trying to catch the action via Twitter ... I missed this particular session . I happen to own Business Model Generation and love it ( bought it full retail price at Amazon.com -- one of only a handful of physical hardcover books I 've bought recently ... the rest are all Kindle eBooks . )  Great to get all the

# %% [markdown]
# **Parsing the sample.**

# %%
par = p.posdep(result)

# %% [markdown]
# **Generating $LaTeX$ file for insight.**

# %%
parp = parse_sentence(par)
generate_latex(latex_code, "coca_snippet", parp)

# %% [markdown]
# **Basic statistics**

# %%
dirs = extract_info(parp) 
print("Mean distance in words when governor on the left: " + str(round(st.mean(dirs["left"]), 2)) 
      + "\nMean distance in words when governor on the right: " + str(round(st.mean(dirs["right"]), 2)))

# %% [markdown]
# ---
#
# **Noteworthy issues:**
# - data must be cleaned more precisely than it's done here,
# - all headers must be removed (may only be a problem for this sample),
# - there are some anomalies that may be hard to remove automatically (although there may not be similar problems when using the full version of COCA),
# - contracted words in this corpus are separated (should they be for our needs?),
# - don't know yet if there is a possibility to parse according to other paradigms than Universal Dependencies ("Stanford"),
# - **(*)** some sentences are too long to fit them on standard A4 format in the $LaTeX$ file,
# - **(*)** there are special characters in the plain text that make a lot of trouble while building the $LaTeX$ file.
#
#
# **(*)** = (not relevant for our cause).
#
# ---

# %% [markdown]
# **To do:**
# 1. Aquire the full COCA corpus.
# 2. Clean the corpus so that there won't be any anomalies.
# 3. Parse whole corpus.
# 4. Find out if it's possible to use other paradigms for parsing.
# 5. Figure out a reliable way of counting dependency distance in words, syllables and letters.
# 6. Conduct a statistical analysis of the results.

# %% [markdown]
# ---
#
# ## Drawing a sample from Polish corpus.

# %%
res = open("results", "r")
sentence = res.readline()

dictionary = {"text": 
            "", "sentences": 
            [{"id": 1, "text": "", "tokens": [{'id': 1, 'text': 'Brakowało', 'upos': 'VERB', 'xpos': 
            'praet:sg:n:imperf', 'feats': 'Aspect=Imp|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act', 
            'head': 0, 'deprel': 'root', 'dspan': (0, 9), 'span': (0, 9), 'lemma': 'brakować'}, 
            {'id': 2, 'text': 'nam', 'upos': 'PRON', 'xpos': 'ppron12:pl:dat:m1:pri', 
            'feats': 'Animacy=Hum|Case=Dat|Gender=Masc|Number=Plur|Person=1|PronType=Prs', 
            'head': 1, 'deprel': 'iobj', 'dspan': (10, 13), 'span': (10, 13), 'lemma': 'my'}, 
            {'id': 3, 'text': 'i', 'upos': 'CCONJ', 'xpos': 'conj', 'head': 4, 'deprel': 'advmod:emph', 
            'dspan': (14, 15), 'span': (14, 15), 'lemma': 'i'}, 
            {'id': 4, 'text': 'im', 'upos': 'PRON', 'xpos': 'ppron3:pl:dat:f:ter:akc:npraep', 
            'feats': 'Animacy=Hum|Case=Dat|Gender=Masc|Number=Plur|Person=3|PrepCase=Npr|PronType=Prs|Variant=Long', 
            'head': 1, 'deprel': 'conj', 'dspan': (16, 18), 'span': (16, 18), 'lemma': 'on'}, 
             {'id': 5, 'text': 'do', 'upos': 'ADP', 'xpos': 'prep:gen', 'feats': 'AdpType=Prep',
            'head': 6, 'deprel': 'case', 'dspan': (19, 21), 'span': (19, 21), 'lemma': 'do'}, 
             {'id': 6, 'text': 'szczęścia', 'upos': 'NOUN', 'xpos': 'subst:sg:gen:n:ncol',
            'feats': 'Case=Gen|Gender=Neut|Number=Sing', 'head': 1, 'deprel': 'obl', 'dspan': (22, 31),
            'span': (22, 31), 'lemma': 'szczęście'}, 
             {'id': 7, 'text': 'ładnej', 'upos': 'ADJ', 'xpos': 'adj:sg:gen:f:pos',
            'feats': 'Case=Gen|Degree=Pos|Gender=Fem|Number=Sing',
            'head': 8, 'deprel': 'amod', 'dspan': (32, 38), 'span': (32, 38), 'lemma': 'ładny'},
            {'id': 8, 'text': 'pogody', 'upos': 'NOUN', 'xpos': 'subst:sg:gen:f',
            'feats': 'Case=Gen|Gender=Fem|Number=Sing', 'head': 1, 'deprel': 'iobj',
            'dspan': (39, 45), 'span': (39, 45), 'lemma': 'pogoda'},
            {'id': 9, 'text': 'oraz', 'upos': 'CCONJ', 'xpos': 'conj', 'head': 11,
            'deprel': 'cc', 'dspan': (46, 50), 'span': (46, 50), 'lemma': 'oraz'},
            {'id': 10, 'text': 'lepszego', 'upos': 'ADJ', 'xpos':
            'adj:sg:gen:m3:com', 'feats': 'Animacy=Inan|Case=Gen|Degree=Cmp|Gender=Masc|Number=Sing',
            'head': 11, 'deprel': 'amod', 'dspan': (51, 59), 'span': (51, 59), 'lemma': 'dobry'}, 
            {'id': 11, 'text': 'nastroju', 'upos': 'NOUN', 'xpos': 'subst:sg:gen:m3', 'feats':
            'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'head': 8, 'deprel': 'conj',
            'dspan': (60, 68), 'span': (60, 68), 'lemma': 'nastrój'}, {'id': 12, 'text':
            '.', 'upos': 'PUNCT', 'xpos': 'interp', 'feats': 'PunctType=Peri',
            'head': 1, 'deprel': 'punct', 'dspan': (68, 69), 'span': (68, 69), 'lemma': '.'}]}]}
dictionary
parse = parse_sentence(dictionary)
generate_latex(latex_code, "polish", parse)

# %% [markdown]
# ---
#
# ## ConLLU conversion test.

# %%
all["sentences"][0]["tokens"][6]
# Out:
# {'id': 7,
#  'text': 'and',
#  'upos': 'CCONJ',
#  'xpos': 'CC',
#  'head': 8,
#  'deprel': 'cc',
#  'dspan': (22, 25),
#  'span': (22, 25)}

# %%
import csv

with open("columns.csv", "r") as csvfile:
    reader = csv.reader(csvfile, dialect='excel-tab')
    cols = next(reader)

print(cols)
# Out:
# ['governor.position', 'governor.word', 'governor.nkjp.tag', 'governor.pos', 'governor.ms', 'conjunction.word', 'conjunction.nkjp.tag', 'conjunction.pos', 'conjunction.ms', '1.conjunct', '1.dep.label', '1.head.word', '1.head.nkjp.tag', '1.head.pos', '1.head.ms', '1.words', '1.tokens', '1.chars', '2.conjunct', '2.dep.label', '2.head.word', '2.head.nkjp.tag', '2.head.pos', '2.head.ms', '2.words', '2.tokens', '2.chars', 'sentence', 'sent_id', 'genre', 'converted.from.file']

# %%
with open("conll-test.csv", "w") as conll:
    writer = csv.writer(conll)
    writer.writerow(cols)
